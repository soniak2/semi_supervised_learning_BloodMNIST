# %%
import medmnist
from medmnist import BloodMNIST, DermaMNIST, PathMNIST, PneumoniaMNIST, BreastMNIST, OrganAMNIST
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2025-05-22 12:43:33.643636: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import layers, models, optimizers, callbacks, Model, Input
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import precision_recall_curve
import time

# %%
'''
train_dataset = BloodMNIST(split="train", download=True, transform=None)
test_dataset = BloodMNIST(split="test", download=True, transform=None)
val_dataset = BloodMNIST(split="val", download=True, transform=None)
print(train_dataset)
print(test_dataset)
print(val_dataset)
'''

train_dataset = DermaMNIST(split="train", download=True, transform=None)
test_dataset = DermaMNIST(split="test", download=True, transform=None)
val_dataset = DermaMNIST(split="val", download=True, transform=None)
print(train_dataset)
print(test_dataset)
print(val_dataset)
# Out:
# Dataset DermaMNIST of size 28 (dermamnist)
#     Number of datapoints: 7007
#     Root location: /mnt/bcache/home/sonia/.medmnist
#     Split: train
#     Task: multi-class
#     Number of channels: 3
#     Meaning of labels: {'0': 'actinic keratoses and intraepithelial carcinoma', '1': 'basal cell carcinoma', '2': 'benign keratosis-like lesions', '3': 'dermatofibroma', '4': 'melanoma', '5': 'melanocytic nevi', '6': 'vascular lesions'}
#     Number of samples: {'train': 7007, 'val': 1003, 'test': 2005}
#     Description: The DermaMNIST is based on the HAM10000, a large collection of multi-source dermatoscopic images of common pigmented skin lesions. The dataset consists of 10,015 dermatoscopic images categorized as 7 different diseases, formulized as a multi-class classification task. We split the images into training, validation and test set with a ratio of 7:1:2. The source images of 3×600×450 are resized into 3×28×28.
#     License: CC BY-NC 4.0
# Dataset DermaMNIST of size 28 (dermamnist)
#     Number of datapoints: 2005
#     Root location: /mnt/bcache/home/sonia/.medmnist
#     Split: test
#     Task: multi-class
#     Number of channels: 3
#     Meaning of labels: {'0': 'actinic keratoses and intraepithelial carcinoma', '1': 'basal cell carcinoma', '2': 'benign keratosis-like lesions', '3': 'dermatofibroma', '4': 'melanoma', '5': 'melanocytic nevi', '6': 'vascular lesions'}
#     Number of samples: {'train': 7007, 'val': 1003, 'test': 2005}
#     Description: The DermaMNIST is based on the HAM10000, a large collection of multi-source dermatoscopic images of common pigmented skin lesions. The dataset consists of 10,015 dermatoscopic images categorized as 7 different diseases, formulized as a multi-class classification task. We split the images into training, validation and test set with a ratio of 7:1:2. The source images of 3×600×450 are resized into 3×28×28.
#     License: CC BY-NC 4.0
# Dataset DermaMNIST of size 28 (dermamnist)
#     Number of datapoints: 1003
#     Root location: /mnt/bcache/home/sonia/.medmnist
#     Split: val
#     Task: multi-class
#     Number of channels: 3
#     Meaning of labels: {'0': 'actinic keratoses and intraepithelial carcinoma', '1': 'basal cell carcinoma', '2': 'benign keratosis-like lesions', '3': 'dermatofibroma', '4': 'melanoma', '5': 'melanocytic nevi', '6': 'vascular lesions'}
#     Number of samples: {'train': 7007, 'val': 1003, 'test': 2005}
#     Description: The DermaMNIST is based on the HAM10000, a large collection of multi-source dermatoscopic images of common pigmented skin lesions. The dataset consists of 10,015 dermatoscopic images categorized as 7 different diseases, formulized as a multi-class classification task. We split the images into training, validation and test set with a ratio of 7:1:2. The source images of 3×600×450 are resized into 3×28×28.
#     License: CC BY-NC 4.0

# %%
train_dataset = PathMNIST(split="train", download=True, transform=None)
test_dataset = PathMNIST(split="test", download=True, transform=None)
val_dataset = PathMNIST(split="val", download=True, transform=None)
print(train_dataset)
print(test_dataset)
print(val_dataset)
# Out:
# Dataset PathMNIST of size 28 (pathmnist)
#     Number of datapoints: 89996
#     Root location: /mnt/bcache/home/sonia/.medmnist
#     Split: train
#     Task: multi-class
#     Number of channels: 3
#     Meaning of labels: {'0': 'adipose', '1': 'background', '2': 'debris', '3': 'lymphocytes', '4': 'mucus', '5': 'smooth muscle', '6': 'normal colon mucosa', '7': 'cancer-associated stroma', '8': 'colorectal adenocarcinoma epithelium'}
#     Number of samples: {'train': 89996, 'val': 10004, 'test': 7180}
#     Description: The PathMNIST is based on a prior study for predicting survival from colorectal cancer histology slides, providing a dataset (NCT-CRC-HE-100K) of 100,000 non-overlapping image patches from hematoxylin & eosin stained histological images, and a test dataset (CRC-VAL-HE-7K) of 7,180 image patches from a different clinical center. The dataset is comprised of 9 types of tissues, resulting in a multi-class classification task. We resize the source images of 3×224×224 into 3×28×28, and split NCT-CRC-HE-100K into training and validation set with a ratio of 9:1. The CRC-VAL-HE-7K is treated as the test set.
#     License: CC BY 4.0
# Dataset PathMNIST of size 28 (pathmnist)
#     Number of datapoints: 7180
#     Root location: /mnt/bcache/home/sonia/.medmnist
#     Split: test
#     Task: multi-class
#     Number of channels: 3
#     Meaning of labels: {'0': 'adipose', '1': 'background', '2': 'debris', '3': 'lymphocytes', '4': 'mucus', '5': 'smooth muscle', '6': 'normal colon mucosa', '7': 'cancer-associated stroma', '8': 'colorectal adenocarcinoma epithelium'}
#     Number of samples: {'train': 89996, 'val': 10004, 'test': 7180}
#     Description: The PathMNIST is based on a prior study for predicting survival from colorectal cancer histology slides, providing a dataset (NCT-CRC-HE-100K) of 100,000 non-overlapping image patches from hematoxylin & eosin stained histological images, and a test dataset (CRC-VAL-HE-7K) of 7,180 image patches from a different clinical center. The dataset is comprised of 9 types of tissues, resulting in a multi-class classification task. We resize the source images of 3×224×224 into 3×28×28, and split NCT-CRC-HE-100K into training and validation set with a ratio of 9:1. The CRC-VAL-HE-7K is treated as the test set.
#     License: CC BY 4.0
# Dataset PathMNIST of size 28 (pathmnist)
#     Number of datapoints: 10004
#     Root location: /mnt/bcache/home/sonia/.medmnist
#     Split: val
#     Task: multi-class
#     Number of channels: 3
#     Meaning of labels: {'0': 'adipose', '1': 'background', '2': 'debris', '3': 'lymphocytes', '4': 'mucus', '5': 'smooth muscle', '6': 'normal colon mucosa', '7': 'cancer-associated stroma', '8': 'colorectal adenocarcinoma epithelium'}
#     Number of samples: {'train': 89996, 'val': 10004, 'test': 7180}
#     Description: The PathMNIST is based on a prior study for predicting survival from colorectal cancer histology slides, providing a dataset (NCT-CRC-HE-100K) of 100,000 non-overlapping image patches from hematoxylin & eosin stained histological images, and a test dataset (CRC-VAL-HE-7K) of 7,180 image patches from a different clinical center. The dataset is comprised of 9 types of tissues, resulting in a multi-class classification task. We resize the source images of 3×224×224 into 3×28×28, and split NCT-CRC-HE-100K into training and validation set with a ratio of 9:1. The CRC-VAL-HE-7K is treated as the test set.
#     License: CC BY 4.0

# %%
train_dataset = PneumoniaMNIST(split="train", download=True, transform=None)
test_dataset = PneumoniaMNIST(split="test", download=True, transform=None)
val_dataset = PneumoniaMNIST(split="val", download=True, transform=None)
print(train_dataset)
print(test_dataset)
print(val_dataset)
# Out:
# Dataset PneumoniaMNIST of size 28 (pneumoniamnist)
#     Number of datapoints: 4708
#     Root location: /mnt/bcache/home/sonia/.medmnist
#     Split: train
#     Task: binary-class
#     Number of channels: 1
#     Meaning of labels: {'0': 'normal', '1': 'pneumonia'}
#     Number of samples: {'train': 4708, 'val': 524, 'test': 624}
#     Description: The PneumoniaMNIST is based on a prior dataset of 5,856 pediatric chest X-Ray images. The task is binary-class classification of pneumonia against normal. We split the source training set with a ratio of 9:1 into training and validation set and use its source validation set as the test set. The source images are gray-scale, and their sizes are (384−2,916)×(127−2,713). We center-crop the images and resize them into 1×28×28.
#     License: CC BY 4.0
# Dataset PneumoniaMNIST of size 28 (pneumoniamnist)
#     Number of datapoints: 624
#     Root location: /mnt/bcache/home/sonia/.medmnist
#     Split: test
#     Task: binary-class
#     Number of channels: 1
#     Meaning of labels: {'0': 'normal', '1': 'pneumonia'}
#     Number of samples: {'train': 4708, 'val': 524, 'test': 624}
#     Description: The PneumoniaMNIST is based on a prior dataset of 5,856 pediatric chest X-Ray images. The task is binary-class classification of pneumonia against normal. We split the source training set with a ratio of 9:1 into training and validation set and use its source validation set as the test set. The source images are gray-scale, and their sizes are (384−2,916)×(127−2,713). We center-crop the images and resize them into 1×28×28.
#     License: CC BY 4.0
# Dataset PneumoniaMNIST of size 28 (pneumoniamnist)
#     Number of datapoints: 524
#     Root location: /mnt/bcache/home/sonia/.medmnist
#     Split: val
#     Task: binary-class
#     Number of channels: 1
#     Meaning of labels: {'0': 'normal', '1': 'pneumonia'}
#     Number of samples: {'train': 4708, 'val': 524, 'test': 624}
#     Description: The PneumoniaMNIST is based on a prior dataset of 5,856 pediatric chest X-Ray images. The task is binary-class classification of pneumonia against normal. We split the source training set with a ratio of 9:1 into training and validation set and use its source validation set as the test set. The source images are gray-scale, and their sizes are (384−2,916)×(127−2,713). We center-crop the images and resize them into 1×28×28.
#     License: CC BY 4.0

# %%
train_dataset = OrganAMNIST(split="train", download=True, transform=None)
test_dataset = OrganAMNIST(split="test", download=True, transform=None)
val_dataset = OrganAMNIST(split="val", download=True, transform=None)
print(train_dataset)
print(test_dataset)
print(val_dataset)
# Out:
# Dataset OrganAMNIST of size 28 (organamnist)
#     Number of datapoints: 34561
#     Root location: /mnt/bcache/home/sonia/.medmnist
#     Split: train
#     Task: multi-class
#     Number of channels: 1
#     Meaning of labels: {'0': 'bladder', '1': 'femur-left', '2': 'femur-right', '3': 'heart', '4': 'kidney-left', '5': 'kidney-right', '6': 'liver', '7': 'lung-left', '8': 'lung-right', '9': 'pancreas', '10': 'spleen'}
#     Number of samples: {'train': 34561, 'val': 6491, 'test': 17778}
#     Description: The OrganAMNIST is based on 3D computed tomography (CT) images from Liver Tumor Segmentation Benchmark (LiTS). It is renamed from OrganMNIST_Axial (in MedMNIST v1) for simplicity. We use bounding-box annotations of 11 body organs from another study to obtain the organ labels. Hounsfield-Unit (HU) of the 3D images are transformed into gray-scale with an abdominal window. We crop 2D images from the center slices of the 3D bounding boxes in axial views (planes). The images are resized into 1×28×28 to perform multi-class classification of 11 body organs. 115 and 16 CT scans from the source training set are used as training and validation set, respectively. The 70 CT scans from the source test set are treated as the test set.
#     License: CC BY 4.0
# Dataset OrganAMNIST of size 28 (organamnist)
#     Number of datapoints: 17778
#     Root location: /mnt/bcache/home/sonia/.medmnist
#     Split: test
#     Task: multi-class
#     Number of channels: 1
#     Meaning of labels: {'0': 'bladder', '1': 'femur-left', '2': 'femur-right', '3': 'heart', '4': 'kidney-left', '5': 'kidney-right', '6': 'liver', '7': 'lung-left', '8': 'lung-right', '9': 'pancreas', '10': 'spleen'}
#     Number of samples: {'train': 34561, 'val': 6491, 'test': 17778}
#     Description: The OrganAMNIST is based on 3D computed tomography (CT) images from Liver Tumor Segmentation Benchmark (LiTS). It is renamed from OrganMNIST_Axial (in MedMNIST v1) for simplicity. We use bounding-box annotations of 11 body organs from another study to obtain the organ labels. Hounsfield-Unit (HU) of the 3D images are transformed into gray-scale with an abdominal window. We crop 2D images from the center slices of the 3D bounding boxes in axial views (planes). The images are resized into 1×28×28 to perform multi-class classification of 11 body organs. 115 and 16 CT scans from the source training set are used as training and validation set, respectively. The 70 CT scans from the source test set are treated as the test set.
#     License: CC BY 4.0
# Dataset OrganAMNIST of size 28 (organamnist)
#     Number of datapoints: 6491
#     Root location: /mnt/bcache/home/sonia/.medmnist
#     Split: val
#     Task: multi-class
#     Number of channels: 1
#     Meaning of labels: {'0': 'bladder', '1': 'femur-left', '2': 'femur-right', '3': 'heart', '4': 'kidney-left', '5': 'kidney-right', '6': 'liver', '7': 'lung-left', '8': 'lung-right', '9': 'pancreas', '10': 'spleen'}
#     Number of samples: {'train': 34561, 'val': 6491, 'test': 17778}
#     Description: The OrganAMNIST is based on 3D computed tomography (CT) images from Liver Tumor Segmentation Benchmark (LiTS). It is renamed from OrganMNIST_Axial (in MedMNIST v1) for simplicity. We use bounding-box annotations of 11 body organs from another study to obtain the organ labels. Hounsfield-Unit (HU) of the 3D images are transformed into gray-scale with an abdominal window. We crop 2D images from the center slices of the 3D bounding boxes in axial views (planes). The images are resized into 1×28×28 to perform multi-class classification of 11 body organs. 115 and 16 CT scans from the source training set are used as training and validation set, respectively. The 70 CT scans from the source test set are treated as the test set.
#     License: CC BY 4.0

# %%
class BloodMNISTDataLoader:
    def __init__(self):
        self.train_dataset = DermaMNIST(split="train", download=True, transform=None)
        self.val_dataset = DermaMNIST(split="val", download=True, transform=None)
        self.test_dataset = DermaMNIST(split="test", download=True, transform=None)

        self.X_train, self.y_train = self._prepare_data(self.train_dataset)
        self.X_val, self.y_val = self._prepare_data(self.val_dataset)
        self.X_test, self.y_test = self._prepare_data(self.test_dataset)

        print(f"X_train shape: {self.X_train.shape}, y_train shape: {self.y_train.shape}")
        print(f"X_val shape: {self.X_val.shape}, y_val shape: {self.y_val.shape}")
        print(f"X_test shape: {self.X_test.shape}, y_test shape: {self.y_test.shape}")

    def _prepare_data(self, dataset):
        X = dataset.imgs.astype("float32") / 255.0
        X = X.reshape(-1, 28, 28, 3)
        y = dataset.labels.squeeze()
        y = to_categorical(y, num_classes=len(np.unique(y)))
        return X, y

    def show_sample_images(self, n = 10, dataset = "test"):
        if dataset == "train":
            X, y = self.X_train, self.y_train
        elif dataset == "val":
            X, y = self.X_val, self.y_val
        else:
            X, y = self.X_test, self.y_test

        plt.figure(figsize=(n, 2))
        for i in range(n):
            plt.subplot(1, n, i + 1)
            plt.imshow(X[i])
            label = np.argmax(y[i])
            plt.title(f"Label: {label}")
            plt.axis("off")
        plt.tight_layout()
        plt.show()

    def plot_label_histograms(self):
        fig, axes = plt.subplots(1, 3, figsize=(15, 5))

        for idx, (name, y) in enumerate([
            ("Training set", self.y_train),
            ("Validation set", self.y_val),
            ("Test set", self.y_test)
        ]):
            labels = np.argmax(y, axis=1)
            unique, counts = np.unique(labels, return_counts=True)
            axes[idx].bar(unique, counts, color=['blue', 'green', 'red'][idx])
            axes[idx].set_title(name)
            axes[idx].set_xlabel("Class")
            axes[idx].set_ylabel("Count")

        plt.savefig("hist_DermaMNIST.png")
        plt.tight_layout()
        plt.show()

# %%
class PneumoniaMNISTDataLoader:
    def __init__(self):
        self.train_dataset = OrganAMNIST(split="train", download=True, transform=None)
        self.val_dataset = OrganAMNIST(split="val", download=True, transform=None)
        self.test_dataset = OrganAMNIST(split="test", download=True, transform=None)

        self.X_train, self.y_train = self._prepare_data(self.train_dataset)
        self.X_val, self.y_val = self._prepare_data(self.val_dataset)
        self.X_test, self.y_test = self._prepare_data(self.test_dataset)

        print(f"X_train shape: {self.X_train.shape}, y_train shape: {self.y_train.shape}")
        print(f"X_val shape: {self.X_val.shape}, y_val shape: {self.y_val.shape}")
        print(f"X_test shape: {self.X_test.shape}, y_test shape: {self.y_test.shape}")

    def _prepare_data(self, dataset):
        X = dataset.imgs.astype("float32") / 255.0
        X = X.reshape(-1, 28, 28, 1)
        y = dataset.labels.squeeze()
        y = to_categorical(y, num_classes=len(np.unique(y)))
        return X, y

    def show_sample_images(self, n = 10, dataset = "test"):
        if dataset == "train":
            X, y = self.X_train, self.y_train
        elif dataset == "val":
            X, y = self.X_val, self.y_val
        else:
            X, y = self.X_test, self.y_test

        plt.figure(figsize=(n, 2))
        for i in range(n):
            plt.subplot(1, n, i + 1)
            plt.imshow(X[i])
            label = np.argmax(y[i])
            plt.title(f"Label: {label}")
            plt.axis("off")
        plt.tight_layout()
        plt.show()

    def plot_label_histograms(self):
        fig, axes = plt.subplots(1, 3, figsize=(15, 5))

        for idx, (name, y) in enumerate([
            ("Training set", self.y_train),
            ("Validation set", self.y_val),
            ("Test set", self.y_test)
        ]):
            labels = np.argmax(y, axis=1)
            unique, counts = np.unique(labels, return_counts=True)
            axes[idx].bar(unique, counts, color=['blue', 'green', 'red'][idx])
            axes[idx].set_title(name)
            axes[idx].set_xlabel("Class")
            axes[idx].set_ylabel("Count")

        plt.savefig("hist_OrganAMNIST.png")
        plt.tight_layout()
        plt.show()

# %%
loader = PneumoniaMNISTDataLoader()
#loader = BloodMNISTDataLoader()

loader.show_sample_images(n=15, dataset="val")
loader.plot_label_histograms()

X_train, y_train = loader.X_train, loader.y_train
X_val, y_val = loader.X_val, loader.y_val
X_test, y_test = loader.X_test, loader.y_test

#print(y_train[0])
# Out:
# X_train shape: (34561, 28, 28, 1), y_train shape: (34561, 11)
# X_val shape: (6491, 28, 28, 1), y_val shape: (6491, 11)
# X_test shape: (17778, 28, 28, 1), y_test shape: (17778, 11)

# %%
from tensorflow.keras import layers, Model, Input

def resnet_block(x, filters, downsample=False):
    shortcut = x
    stride = 2 if downsample else 1

    x = layers.Conv2D(filters, 3, strides=stride, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 3, strides=1, padding='same')(x)
    x = layers.BatchNormalization()(x)

    if downsample or shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(filters, 1, strides=stride)(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Add()([x, shortcut])
    x = layers.ReLU()(x)
    return x
    
def ResNet18(input_shape=(28, 28, 3), num_classes=8):
    inputs = Input(shape=input_shape)

    x = layers.Conv2D(32, 3, strides=1, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = resnet_block(x, 32)
    x = resnet_block(x, 32)

    x = resnet_block(x, 64, downsample=True)
    x = resnet_block(x, 64)

    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs, name='ResNet18')

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.0001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras import layers, models, optimizers, callbacks

#model = ResNet_model() 
model = ResNet18(input_shape=(28, 28, 1), num_classes = 11)
#model.summary()

# Callbacks
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.1, 
    patience=5, 
    min_lr=1e-6,
    verbose = True
)
#lr_schedule = callbacks.LearningRateScheduler(lambda epoch, lr: lr * 0.1 if epoch in [50, 75] else lr)

early_stopping = callbacks.EarlyStopping(
    monitor='val_accuracy', 
    patience=20, 
    restore_best_weights=True
)


history = model.fit(X_train, y_train, epochs=20, batch_size=128, validation_data=(X_val, y_val), callbacks = [reduce_lr]) # batch_size -> bigger the better; smaller the faster

# Metrix
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 2
# Epoch 1/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 16s 35ms/step - accuracy: 0.5245 - loss: 1.4578 - val_accuracy: 0.0495 - val_loss: 6.3626 - learning_rate: 1.0000e-04
# Epoch 2/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.8507 - loss: 0.5421 - val_accuracy: 0.4180 - val_loss: 1.5122 - learning_rate: 1.0000e-04
# Epoch 3/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9061 - loss: 0.3549 - val_accuracy: 0.9271 - val_loss: 0.2655 - learning_rate: 1.0000e-04
# Epoch 4/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9231 - loss: 0.2840 - val_accuracy: 0.9509 - val_loss: 0.1835 - learning_rate: 1.0000e-04
# Epoch 5/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9395 - loss: 0.2313 - val_accuracy: 0.9261 - val_loss: 0.2125 - learning_rate: 1.0000e-04
# Epoch 6/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9494 - loss: 0.1972 - val_accuracy: 0.9396 - val_loss: 0.1944 - learning_rate: 1.0000e-04
# Epoch 7/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9592 - loss: 0.1675 - val_accuracy: 0.9538 - val_loss: 0.1610 - learning_rate: 1.0000e-04
# Epoch 8/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9621 - loss: 0.1509 - val_accuracy: 0.9459 - val_loss: 0.1736 - learning_rate: 1.0000e-04
# Epoch 9/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9691 - loss: 0.1299 - val_accuracy: 0.9596 - val_loss: 0.1351 - learning_rate: 1.0000e-04
# Epoch 10/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9724 - loss: 0.1171 - val_accuracy: 0.9709 - val_loss: 0.1320 - learning_rate: 1.0000e-04
# Epoch 11/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9725 - loss: 0.1118 - val_accuracy: 0.9695 - val_loss: 0.1110 - learning_rate: 1.0000e-04
# Epoch 12/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9803 - loss: 0.0930 - val_accuracy: 0.9516 - val_loss: 0.1539 - learning_rate: 1.0000e-04
# Epoch 13/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9793 - loss: 0.0902 - val_accuracy: 0.9713 - val_loss: 0.0973 - learning_rate: 1.0000e-04
# Epoch 14/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9806 - loss: 0.0847 - val_accuracy: 0.9766 - val_loss: 0.0856 - learning_rate: 1.0000e-04
# Epoch 15/15
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9829 - loss: 0.0753 - val_accuracy: 0.9684 - val_loss: 0.1169 - learning_rate: 1.0000e-04
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9064 - loss: 0.2824
# Test accuracy: 0.9070

# %%
x = 0
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'][x:], label='Train Loss', c = 'b')
plt.plot(history.history['val_loss'][x:], label='Val Loss',  c = 'r')
plt.legend()
plt.xlabel('epoch', fontsize = "14")
plt.ylabel('Loss', fontsize = "14")
plt.tight_layout()
#plt.savefig("CNN_loss.png")
#plt.title("Loss")

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'][x:], label='Train Accuracy', c = 'b')
plt.plot(history.history['val_accuracy'][x:], label='Val Accuracy', c = 'r')
plt.legend()
plt.xlabel('epoch', fontsize = "14")
plt.ylabel('Accuracy', fontsize = "14")
#plt.title("Accuracy")
plt.tight_layout()
plt.savefig("PathMNIST_val.png")
plt.show()

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)  

y_true = np.argmax(y_test, axis=1)  
cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues') #, xticklabels=np.arange(2), yticklabels=np.arange(2))
plt.xlabel('Prediction')
plt.ylabel('Label')
#plt.savefig("ResNet18_cm.png")
plt.show()
# Out:
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %%
class AccuracyByDataSize:
    def __init__(self, X_train, y_train, X_val, y_val, X_test, y_test, model_NN, min_epochs=35, max_epochs=100, repetitions=5):
        self.X_train = X_train
        self.y_train = y_train
        self.X_val = X_val
        self.y_val = y_val
        self.X_test = X_test
        self.y_test = y_test
        self.model_class = model_NN
        self.min_epochs = min_epochs
        self.max_epochs = max_epochs
        self.repetitions = repetitions

    def get_random_subset(self, dataset, size):
        X, y = dataset
        indices = np.random.choice(X.shape[0], size=int(size * X.shape[0]), replace=False)
        X_subset = X[indices]
        y_subset = y[indices]
        return X_subset, y_subset

    def train_model_on_random_subset(self, size):
        if size == 1.0:
            X_train_subset, y_train_subset = self.X_train, self.y_train
            X_val_subset, y_val_subset = self.X_val, self.y_val
            X_test_subset, y_test_subset = self.X_test, self.y_test
        else:
            X_train_subset, y_train_subset = self.get_random_subset((self.X_train, self.y_train), size)
            X_val_subset, y_val_subset = self.get_random_subset((self.X_val, self.y_val), size)
            X_test_subset, y_test_subset = self.get_random_subset((self.X_test, self.y_test), size)

        #X_train_subset, y_train_subset = self.get_random_subset((self.X_train, self.y_train), size)
        #X_val_subset, y_val_subset = self.get_random_subset((self.X_val, self.y_val), size)
        #X_test_subset, y_test_subset = self.get_random_subset((self.X_test, self.y_test), size)

        model = self.model_class()
        reduce_lr = ReduceLROnPlateau(
                                        monitor='val_loss', 
                                        factor=0.1, 
                                        patience=5, 
                                        min_lr=1e-6,
                                        verbose = True
                                        )
        
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                        #min_delta=0,
                                                        patience=10,
                                                        verbose=0,
                                                        #mode='auto',
                                                        baseline=None,
                                                        restore_best_weights=True,
                                                        start_from_epoch=40
                                                    )

        history = model.fit(X_train_subset, y_train_subset, 
                            epochs=self.calculate_epochs(size),
                            batch_size=128, 
                            validation_data=(X_val, y_val), #X_val_subset, y_val_subset
                            callbacks= [reduce_lr, early_stop],
                            verbose=True)

        test_loss, test_acc = model.evaluate(X_test, y_test) # X_test_subset, y_test_subset
        print(f"Test accuracy: {test_acc:.4f}")
        return test_acc

    def calculate_epochs(self, size):
        return int(self.min_epochs + (self.max_epochs - self.min_epochs) * (1 - size))

    def calculate_accuracy_by_size(self, sizes):
        means = []
        stds = []
        for size in sizes:
            print(f"=== Training on {int(size * 100)}% of data ===")
            accuracies_for_size = []
            for _ in range(self.repetitions):
                accuracy = self.train_model_on_random_subset(size)
                accuracies_for_size.append(accuracy)
            mean_accuracy = np.mean(accuracies_for_size)
            std_accuracy = np.std(accuracies_for_size)
            means.append(mean_accuracy)
            stds.append(std_accuracy)
        return means, stds


    def plot_accuracy_vs_data_size(self, sizes):
        means, stds = self.calculate_accuracy_by_size(sizes)
        percentages = [int(size * 100) for size in sizes]

        
        plt.figure(figsize=(6, 4))
        plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, elinewidth=2)

        for x, y in zip(percentages, means):
            plt.text(x + 5, y + 0.01, f"{y:.3f}", ha='center', fontsize=10, color='black')
            
        #plt.title("Accuracy vs Data Size", fontsize=18)
        plt.xlabel("Percentage of data used [%]", fontsize=18)
        plt.ylabel("Accuracy - test", fontsize=18)
        plt.ylim((0,1.0))
        plt.xlim((0,105))
        plt.grid(True)
        plt.tight_layout()
        plt.savefig('accuracy_vs_data_size_PneumoniaMNIST.png')
        print('Plot has been saved as accuracy_vs_data_size.png')
        plt.show()

        print("means: ", means)
        print("stds: ", stds)

        return means, stds

# %%
accuracy_model = AccuracyByDataSize(X_train, y_train, X_val, y_val, X_test, y_test, 
                                    model_NN = lambda: ResNet18(input_shape=(28, 28, 1), num_classes=11), 
                                    min_epochs=20, 
                                    max_epochs=70, 
                                    repetitions=1)

sizes = [0.03, 0.05, 0.1, 0.25, 0.5, 0.75, 1.0]
means, stds = accuracy_model.plot_accuracy_vs_data_size(sizes)
print(means)
# Out:
# === Training on 3% of data ===
# Epoch 1/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 564ms/step - accuracy: 0.1368 - loss: 2.6635 - val_accuracy: 0.0277 - val_loss: 2.3939 - learning_rate: 1.0000e-04
# Epoch 2/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.2903 - loss: 2.2196 - val_accuracy: 0.0340 - val_loss: 2.3924 - learning_rate: 1.0000e-04
# Epoch 3/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.3492 - loss: 1.9316 - val_accuracy: 0.1910 - val_loss: 2.3907 - learning_rate: 1.0000e-04
# Epoch 4/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.4204 - loss: 1.7085 - val_accuracy: 0.1591 - val_loss: 2.3948 - learning_rate: 1.0000e-04
# Epoch 5/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5307 - loss: 1.6092 - val_accuracy: 0.1591 - val_loss: 2.4095 - learning_rate: 1.0000e-04
# Epoch 6/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5185 - loss: 1.4955 - val_accuracy: 0.1591 - val_loss: 2.4363 - learning_rate: 1.0000e-04
# Epoch 7/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.5672 - loss: 1.3922 - val_accuracy: 0.1813 - val_loss: 2.4767 - learning_rate: 1.0000e-04
# Epoch 8/68
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5645 - loss: 1.3196
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5641 - loss: 1.3186 - val_accuracy: 0.1189 - val_loss: 2.5375 - learning_rate: 1.0000e-04
# Epoch 9/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.5831 - loss: 1.3063 - val_accuracy: 0.0698 - val_loss: 2.6124 - learning_rate: 1.0000e-05
# Epoch 10/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.5964 - loss: 1.2581 - val_accuracy: 0.0649 - val_loss: 2.6975 - learning_rate: 1.0000e-05
# Epoch 11/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.6164 - loss: 1.2412 - val_accuracy: 0.0584 - val_loss: 2.7960 - learning_rate: 1.0000e-05
# Epoch 12/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.5878 - loss: 1.2503 - val_accuracy: 0.0567 - val_loss: 2.8946 - learning_rate: 1.0000e-05
# Epoch 13/68
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6108 - loss: 1.2360
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1e-06.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.6083 - loss: 1.2387 - val_accuracy: 0.0544 - val_loss: 3.0100 - learning_rate: 1.0000e-05
# Epoch 14/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.6156 - loss: 1.2315 - val_accuracy: 0.0527 - val_loss: 3.1237 - learning_rate: 1.0000e-06
# Epoch 15/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.5904 - loss: 1.2490 - val_accuracy: 0.0510 - val_loss: 3.2381 - learning_rate: 1.0000e-06
# Epoch 16/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.6111 - loss: 1.2612 - val_accuracy: 0.0496 - val_loss: 3.3487 - learning_rate: 1.0000e-06
# Epoch 17/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.6112 - loss: 1.2120 - val_accuracy: 0.0495 - val_loss: 3.4608 - learning_rate: 1.0000e-06
# Epoch 18/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.6250 - loss: 1.2094 - val_accuracy: 0.0495 - val_loss: 3.5561 - learning_rate: 1.0000e-06
# Epoch 19/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.5946 - loss: 1.2270 - val_accuracy: 0.0495 - val_loss: 3.6631 - learning_rate: 1.0000e-06
# Epoch 20/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.6261 - loss: 1.2262 - val_accuracy: 0.0495 - val_loss: 3.7595 - learning_rate: 1.0000e-06
# Epoch 21/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.6154 - loss: 1.2348 - val_accuracy: 0.0495 - val_loss: 3.8498 - learning_rate: 1.0000e-06
# Epoch 22/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.6299 - loss: 1.2334 - val_accuracy: 0.0495 - val_loss: 3.9293 - learning_rate: 1.0000e-06
# Epoch 23/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.6058 - loss: 1.2253 - val_accuracy: 0.0495 - val_loss: 3.9940 - learning_rate: 1.0000e-06
# Epoch 24/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.5863 - loss: 1.2541 - val_accuracy: 0.0495 - val_loss: 4.0437 - learning_rate: 1.0000e-06
# Epoch 25/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.6032 - loss: 1.2478 - val_accuracy: 0.0495 - val_loss: 4.0787 - learning_rate: 1.0000e-06
# Epoch 26/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.6147 - loss: 1.2097 - val_accuracy: 0.0496 - val_loss: 4.1076 - learning_rate: 1.0000e-06
# Epoch 27/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.6260 - loss: 1.2551 - val_accuracy: 0.0499 - val_loss: 4.1281 - learning_rate: 1.0000e-06
# Epoch 28/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.5960 - loss: 1.2596 - val_accuracy: 0.0511 - val_loss: 4.1302 - learning_rate: 1.0000e-06
# Epoch 29/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.6240 - loss: 1.2301 - val_accuracy: 0.0525 - val_loss: 4.1220 - learning_rate: 1.0000e-06
# Epoch 30/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.6189 - loss: 1.2187 - val_accuracy: 0.0536 - val_loss: 4.0914 - learning_rate: 1.0000e-06
# Epoch 31/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.5961 - loss: 1.2561 - val_accuracy: 0.0545 - val_loss: 4.0621 - learning_rate: 1.0000e-06
# Epoch 32/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.6120 - loss: 1.2533 - val_accuracy: 0.0553 - val_loss: 4.0244 - learning_rate: 1.0000e-06
# Epoch 33/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.6043 - loss: 1.2326 - val_accuracy: 0.0559 - val_loss: 3.9842 - learning_rate: 1.0000e-06
# Epoch 34/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.6102 - loss: 1.2474 - val_accuracy: 0.0567 - val_loss: 3.9261 - learning_rate: 1.0000e-06
# Epoch 35/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5919 - loss: 1.2541 - val_accuracy: 0.0587 - val_loss: 3.8662 - learning_rate: 1.0000e-06
# Epoch 36/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.6168 - loss: 1.2324 - val_accuracy: 0.0596 - val_loss: 3.8055 - learning_rate: 1.0000e-06
# Epoch 37/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.6197 - loss: 1.2289 - val_accuracy: 0.0610 - val_loss: 3.7375 - learning_rate: 1.0000e-06
# Epoch 38/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.6117 - loss: 1.2308 - val_accuracy: 0.0636 - val_loss: 3.6719 - learning_rate: 1.0000e-06
# Epoch 39/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.6005 - loss: 1.2566 - val_accuracy: 0.0684 - val_loss: 3.6016 - learning_rate: 1.0000e-06
# Epoch 40/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.6086 - loss: 1.2201 - val_accuracy: 0.0718 - val_loss: 3.5311 - learning_rate: 1.0000e-06
# Epoch 41/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.5915 - loss: 1.2651 - val_accuracy: 0.0741 - val_loss: 3.4488 - learning_rate: 1.0000e-06
# Epoch 42/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.6010 - loss: 1.2616 - val_accuracy: 0.0769 - val_loss: 3.3665 - learning_rate: 1.0000e-06
# Epoch 43/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.6065 - loss: 1.2199 - val_accuracy: 0.0793 - val_loss: 3.2896 - learning_rate: 1.0000e-06
# Epoch 44/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.6050 - loss: 1.2531 - val_accuracy: 0.0810 - val_loss: 3.2013 - learning_rate: 1.0000e-06
# Epoch 45/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.5998 - loss: 1.2431 - val_accuracy: 0.0857 - val_loss: 3.1193 - learning_rate: 1.0000e-06
# Epoch 46/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.5981 - loss: 1.2298 - val_accuracy: 0.0917 - val_loss: 3.0387 - learning_rate: 1.0000e-06
# Epoch 47/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.6166 - loss: 1.2343 - val_accuracy: 0.1000 - val_loss: 2.9472 - learning_rate: 1.0000e-06
# Epoch 48/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.6183 - loss: 1.1872 - val_accuracy: 0.1112 - val_loss: 2.8665 - learning_rate: 1.0000e-06
# Epoch 49/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.5937 - loss: 1.2530 - val_accuracy: 0.1236 - val_loss: 2.7763 - learning_rate: 1.0000e-06
# Epoch 50/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.5806 - loss: 1.2679 - val_accuracy: 0.1365 - val_loss: 2.6834 - learning_rate: 1.0000e-06
# Epoch 51/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6094 - loss: 1.2189 - val_accuracy: 0.1505 - val_loss: 2.5930 - learning_rate: 1.0000e-06
# Epoch 52/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.6145 - loss: 1.2091 - val_accuracy: 0.1659 - val_loss: 2.5026 - learning_rate: 1.0000e-06
# Epoch 53/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.5891 - loss: 1.2756 - val_accuracy: 0.1833 - val_loss: 2.4059 - learning_rate: 1.0000e-06
# Epoch 54/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.6184 - loss: 1.2315 - val_accuracy: 0.1994 - val_loss: 2.3115 - learning_rate: 1.0000e-06
# Epoch 55/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.6255 - loss: 1.2169 - val_accuracy: 0.2165 - val_loss: 2.2202 - learning_rate: 1.0000e-06
# Epoch 56/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.6408 - loss: 1.2001 - val_accuracy: 0.2309 - val_loss: 2.1306 - learning_rate: 1.0000e-06
# Epoch 57/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.6000 - loss: 1.2471 - val_accuracy: 0.2440 - val_loss: 2.0499 - learning_rate: 1.0000e-06
# Epoch 58/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.6181 - loss: 1.2179 - val_accuracy: 0.2574 - val_loss: 1.9684 - learning_rate: 1.0000e-06
# Epoch 59/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.6184 - loss: 1.2049 - val_accuracy: 0.2809 - val_loss: 1.8957 - learning_rate: 1.0000e-06
# Epoch 60/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.6202 - loss: 1.2151 - val_accuracy: 0.3174 - val_loss: 1.8255 - learning_rate: 1.0000e-06
# Epoch 61/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.6196 - loss: 1.1998 - val_accuracy: 0.3779 - val_loss: 1.7585 - learning_rate: 1.0000e-06
# Epoch 62/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.6308 - loss: 1.1965 - val_accuracy: 0.4289 - val_loss: 1.6985 - learning_rate: 1.0000e-06
# Epoch 63/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.5953 - loss: 1.2386 - val_accuracy: 0.4723 - val_loss: 1.6449 - learning_rate: 1.0000e-06
# Epoch 64/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.6014 - loss: 1.2573 - val_accuracy: 0.5099 - val_loss: 1.5956 - learning_rate: 1.0000e-06
# Epoch 65/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.6189 - loss: 1.2149 - val_accuracy: 0.5414 - val_loss: 1.5480 - learning_rate: 1.0000e-06
# Epoch 66/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.6000 - loss: 1.2466 - val_accuracy: 0.5646 - val_loss: 1.5045 - learning_rate: 1.0000e-06
# Epoch 67/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.6183 - loss: 1.2146 - val_accuracy: 0.5791 - val_loss: 1.4642 - learning_rate: 1.0000e-06
# Epoch 68/68
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.5944 - loss: 1.2600 - val_accuracy: 0.5911 - val_loss: 1.4292 - learning_rate: 1.0000e-06
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.5005 - loss: 1.6109
# Test accuracy: 0.5042
# === Training on 5% of data ===
# Epoch 1/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 11s 349ms/step - accuracy: 0.2177 - loss: 2.5140 - val_accuracy: 0.0880 - val_loss: 2.3976 - learning_rate: 1.0000e-04
# Epoch 2/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3350 - loss: 1.8625 - val_accuracy: 0.0878 - val_loss: 2.4303 - learning_rate: 1.0000e-04
# Epoch 3/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.5051 - loss: 1.5591 - val_accuracy: 0.0568 - val_loss: 2.5103 - learning_rate: 1.0000e-04
# Epoch 4/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.5565 - loss: 1.3973 - val_accuracy: 0.0495 - val_loss: 2.6991 - learning_rate: 1.0000e-04
# Epoch 5/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.5726 - loss: 1.2870 - val_accuracy: 0.0495 - val_loss: 2.9664 - learning_rate: 1.0000e-04
# Epoch 6/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5912 - loss: 1.2403
# Epoch 6: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.5918 - loss: 1.2380 - val_accuracy: 0.0495 - val_loss: 3.2883 - learning_rate: 1.0000e-04
# Epoch 7/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6297 - loss: 1.1674 - val_accuracy: 0.0495 - val_loss: 3.5966 - learning_rate: 1.0000e-05
# Epoch 8/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6277 - loss: 1.1649 - val_accuracy: 0.0495 - val_loss: 3.9195 - learning_rate: 1.0000e-05
# Epoch 9/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6176 - loss: 1.1581 - val_accuracy: 0.0495 - val_loss: 4.2378 - learning_rate: 1.0000e-05
# Epoch 10/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6279 - loss: 1.1529 - val_accuracy: 0.0495 - val_loss: 4.5317 - learning_rate: 1.0000e-05
# Epoch 11/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6387 - loss: 1.1386
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1e-06.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6391 - loss: 1.1378 - val_accuracy: 0.0495 - val_loss: 4.7896 - learning_rate: 1.0000e-05
# Epoch 12/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6343 - loss: 1.1437 - val_accuracy: 0.0495 - val_loss: 5.0066 - learning_rate: 1.0000e-06
# Epoch 13/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6491 - loss: 1.1193 - val_accuracy: 0.0495 - val_loss: 5.1919 - learning_rate: 1.0000e-06
# Epoch 14/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6509 - loss: 1.1197 - val_accuracy: 0.0495 - val_loss: 5.3393 - learning_rate: 1.0000e-06
# Epoch 15/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6329 - loss: 1.1387 - val_accuracy: 0.0495 - val_loss: 5.4567 - learning_rate: 1.0000e-06
# Epoch 16/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6585 - loss: 1.1063 - val_accuracy: 0.0495 - val_loss: 5.5331 - learning_rate: 1.0000e-06
# Epoch 17/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6512 - loss: 1.1071 - val_accuracy: 0.0495 - val_loss: 5.5768 - learning_rate: 1.0000e-06
# Epoch 18/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6350 - loss: 1.1204 - val_accuracy: 0.0495 - val_loss: 5.5769 - learning_rate: 1.0000e-06
# Epoch 19/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6309 - loss: 1.1281 - val_accuracy: 0.0495 - val_loss: 5.5334 - learning_rate: 1.0000e-06
# Epoch 20/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6484 - loss: 1.1192 - val_accuracy: 0.0495 - val_loss: 5.4483 - learning_rate: 1.0000e-06
# Epoch 21/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6430 - loss: 1.1332 - val_accuracy: 0.0495 - val_loss: 5.3326 - learning_rate: 1.0000e-06
# Epoch 22/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6271 - loss: 1.1679 - val_accuracy: 0.0495 - val_loss: 5.1896 - learning_rate: 1.0000e-06
# Epoch 23/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6411 - loss: 1.1197 - val_accuracy: 0.0495 - val_loss: 5.0281 - learning_rate: 1.0000e-06
# Epoch 24/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.6401 - loss: 1.1214 - val_accuracy: 0.0495 - val_loss: 4.8453 - learning_rate: 1.0000e-06
# Epoch 25/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6401 - loss: 1.1208 - val_accuracy: 0.0501 - val_loss: 4.6529 - learning_rate: 1.0000e-06
# Epoch 26/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.6250 - loss: 1.1254 - val_accuracy: 0.0530 - val_loss: 4.4532 - learning_rate: 1.0000e-06
# Epoch 27/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.6239 - loss: 1.1282 - val_accuracy: 0.0547 - val_loss: 4.2499 - learning_rate: 1.0000e-06
# Epoch 28/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.6221 - loss: 1.1273 - val_accuracy: 0.0558 - val_loss: 4.0548 - learning_rate: 1.0000e-06
# Epoch 29/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6471 - loss: 1.1084 - val_accuracy: 0.0578 - val_loss: 3.8616 - learning_rate: 1.0000e-06
# Epoch 30/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6558 - loss: 1.1349 - val_accuracy: 0.0641 - val_loss: 3.6687 - learning_rate: 1.0000e-06
# Epoch 31/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6517 - loss: 1.1181 - val_accuracy: 0.0724 - val_loss: 3.4737 - learning_rate: 1.0000e-06
# Epoch 32/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6523 - loss: 1.1079 - val_accuracy: 0.0817 - val_loss: 3.2756 - learning_rate: 1.0000e-06
# Epoch 33/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6498 - loss: 1.0952 - val_accuracy: 0.0904 - val_loss: 3.0780 - learning_rate: 1.0000e-06
# Epoch 34/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.6515 - loss: 1.1062 - val_accuracy: 0.1018 - val_loss: 2.8794 - learning_rate: 1.0000e-06
# Epoch 35/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6553 - loss: 1.1028 - val_accuracy: 0.1154 - val_loss: 2.6834 - learning_rate: 1.0000e-06
# Epoch 36/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.6430 - loss: 1.1028 - val_accuracy: 0.1300 - val_loss: 2.4931 - learning_rate: 1.0000e-06
# Epoch 37/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6439 - loss: 1.1152 - val_accuracy: 0.1447 - val_loss: 2.3114 - learning_rate: 1.0000e-06
# Epoch 38/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.6438 - loss: 1.1131 - val_accuracy: 0.1599 - val_loss: 2.1375 - learning_rate: 1.0000e-06
# Epoch 39/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.6189 - loss: 1.1468 - val_accuracy: 0.2075 - val_loss: 1.9791 - learning_rate: 1.0000e-06
# Epoch 40/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.6481 - loss: 1.0941 - val_accuracy: 0.2765 - val_loss: 1.8350 - learning_rate: 1.0000e-06
# Epoch 41/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6684 - loss: 1.0830 - val_accuracy: 0.3397 - val_loss: 1.7078 - learning_rate: 1.0000e-06
# Epoch 42/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.6351 - loss: 1.1426 - val_accuracy: 0.4069 - val_loss: 1.5971 - learning_rate: 1.0000e-06
# Epoch 43/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6488 - loss: 1.1206 - val_accuracy: 0.4722 - val_loss: 1.5020 - learning_rate: 1.0000e-06
# Epoch 44/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.6497 - loss: 1.0850 - val_accuracy: 0.5200 - val_loss: 1.4204 - learning_rate: 1.0000e-06
# Epoch 45/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6451 - loss: 1.1137 - val_accuracy: 0.5566 - val_loss: 1.3520 - learning_rate: 1.0000e-06
# Epoch 46/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.6259 - loss: 1.1354 - val_accuracy: 0.5837 - val_loss: 1.2936 - learning_rate: 1.0000e-06
# Epoch 47/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6475 - loss: 1.1129 - val_accuracy: 0.6053 - val_loss: 1.2443 - learning_rate: 1.0000e-06
# Epoch 48/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.6592 - loss: 1.1043 - val_accuracy: 0.6181 - val_loss: 1.2034 - learning_rate: 1.0000e-06
# Epoch 49/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6429 - loss: 1.1162 - val_accuracy: 0.6318 - val_loss: 1.1688 - learning_rate: 1.0000e-06
# Epoch 50/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6338 - loss: 1.1250 - val_accuracy: 0.6430 - val_loss: 1.1399 - learning_rate: 1.0000e-06
# Epoch 51/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.6571 - loss: 1.0911 - val_accuracy: 0.6498 - val_loss: 1.1161 - learning_rate: 1.0000e-06
# Epoch 52/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.6513 - loss: 1.1057 - val_accuracy: 0.6544 - val_loss: 1.0963 - learning_rate: 1.0000e-06
# Epoch 53/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.6622 - loss: 1.0871 - val_accuracy: 0.6603 - val_loss: 1.0801 - learning_rate: 1.0000e-06
# Epoch 54/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6593 - loss: 1.0899 - val_accuracy: 0.6631 - val_loss: 1.0665 - learning_rate: 1.0000e-06
# Epoch 55/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6320 - loss: 1.1074 - val_accuracy: 0.6674 - val_loss: 1.0550 - learning_rate: 1.0000e-06
# Epoch 56/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6561 - loss: 1.0810 - val_accuracy: 0.6683 - val_loss: 1.0453 - learning_rate: 1.0000e-06
# Epoch 57/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6380 - loss: 1.0991 - val_accuracy: 0.6691 - val_loss: 1.0374 - learning_rate: 1.0000e-06
# Epoch 58/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6363 - loss: 1.1039 - val_accuracy: 0.6692 - val_loss: 1.0305 - learning_rate: 1.0000e-06
# Epoch 59/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6414 - loss: 1.1039 - val_accuracy: 0.6691 - val_loss: 1.0251 - learning_rate: 1.0000e-06
# Epoch 60/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6501 - loss: 1.1106 - val_accuracy: 0.6680 - val_loss: 1.0202 - learning_rate: 1.0000e-06
# Epoch 61/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.6445 - loss: 1.0906 - val_accuracy: 0.6678 - val_loss: 1.0158 - learning_rate: 1.0000e-06
# Epoch 62/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.6414 - loss: 1.1063 - val_accuracy: 0.6692 - val_loss: 1.0120 - learning_rate: 1.0000e-06
# Epoch 63/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6543 - loss: 1.0791 - val_accuracy: 0.6699 - val_loss: 1.0087 - learning_rate: 1.0000e-06
# Epoch 64/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6749 - loss: 1.0820 - val_accuracy: 0.6708 - val_loss: 1.0060 - learning_rate: 1.0000e-06
# Epoch 65/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6472 - loss: 1.0898 - val_accuracy: 0.6697 - val_loss: 1.0036 - learning_rate: 1.0000e-06
# Epoch 66/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6601 - loss: 1.0705 - val_accuracy: 0.6697 - val_loss: 1.0013 - learning_rate: 1.0000e-06
# Epoch 67/67
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.6566 - loss: 1.0925 - val_accuracy: 0.6695 - val_loss: 0.9992 - learning_rate: 1.0000e-06
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.5582 - loss: 1.2954
# Test accuracy: 0.5583
# === Training on 10% of data ===
# Epoch 1/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.1704 - loss: 2.2543 - val_accuracy: 0.1095 - val_loss: 2.3801 - learning_rate: 1.0000e-04
# Epoch 2/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.4855 - loss: 1.6006 - val_accuracy: 0.0495 - val_loss: 2.5088 - learning_rate: 1.0000e-04
# Epoch 3/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.5521 - loss: 1.3279 - val_accuracy: 0.0495 - val_loss: 2.8375 - learning_rate: 1.0000e-04
# Epoch 4/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6548 - loss: 1.1629 - val_accuracy: 0.0495 - val_loss: 3.3329 - learning_rate: 1.0000e-04
# Epoch 5/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7008 - loss: 1.0194 - val_accuracy: 0.0495 - val_loss: 3.8675 - learning_rate: 1.0000e-04
# Epoch 6/65
# 26/27 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7330 - loss: 0.9142
# Epoch 6: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7338 - loss: 0.9129 - val_accuracy: 0.0495 - val_loss: 4.2641 - learning_rate: 1.0000e-04
# Epoch 7/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7521 - loss: 0.8535 - val_accuracy: 0.0495 - val_loss: 4.5086 - learning_rate: 1.0000e-05
# Epoch 8/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7569 - loss: 0.8437 - val_accuracy: 0.0495 - val_loss: 4.6893 - learning_rate: 1.0000e-05
# Epoch 9/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7760 - loss: 0.8056 - val_accuracy: 0.0495 - val_loss: 4.7477 - learning_rate: 1.0000e-05
# Epoch 10/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7642 - loss: 0.8347 - val_accuracy: 0.0495 - val_loss: 4.7284 - learning_rate: 1.0000e-05
# Epoch 11/65
# 26/27 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7587 - loss: 0.8242
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1e-06.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7595 - loss: 0.8233 - val_accuracy: 0.0495 - val_loss: 4.6342 - learning_rate: 1.0000e-05
# Epoch 12/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7648 - loss: 0.8161 - val_accuracy: 0.0495 - val_loss: 4.4298 - learning_rate: 1.0000e-06
# Epoch 13/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7850 - loss: 0.7910 - val_accuracy: 0.0556 - val_loss: 4.1722 - learning_rate: 1.0000e-06
# Epoch 14/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7737 - loss: 0.8092 - val_accuracy: 0.0707 - val_loss: 3.8618 - learning_rate: 1.0000e-06
# Epoch 15/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7837 - loss: 0.7975 - val_accuracy: 0.0932 - val_loss: 3.5099 - learning_rate: 1.0000e-06
# Epoch 16/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7795 - loss: 0.7838 - val_accuracy: 0.1403 - val_loss: 3.1331 - learning_rate: 1.0000e-06
# Epoch 17/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7794 - loss: 0.8055 - val_accuracy: 0.1759 - val_loss: 2.7483 - learning_rate: 1.0000e-06
# Epoch 18/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7753 - loss: 0.8094 - val_accuracy: 0.1883 - val_loss: 2.3626 - learning_rate: 1.0000e-06
# Epoch 19/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7801 - loss: 0.7975 - val_accuracy: 0.2294 - val_loss: 1.9985 - learning_rate: 1.0000e-06
# Epoch 20/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7673 - loss: 0.8086 - val_accuracy: 0.3556 - val_loss: 1.6687 - learning_rate: 1.0000e-06
# Epoch 21/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7722 - loss: 0.7991 - val_accuracy: 0.5220 - val_loss: 1.3888 - learning_rate: 1.0000e-06
# Epoch 22/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7747 - loss: 0.8049 - val_accuracy: 0.6421 - val_loss: 1.1742 - learning_rate: 1.0000e-06
# Epoch 23/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7795 - loss: 0.7868 - val_accuracy: 0.7039 - val_loss: 1.0172 - learning_rate: 1.0000e-06
# Epoch 24/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7711 - loss: 0.8009 - val_accuracy: 0.7463 - val_loss: 0.9037 - learning_rate: 1.0000e-06
# Epoch 25/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7829 - loss: 0.8012 - val_accuracy: 0.7746 - val_loss: 0.8266 - learning_rate: 1.0000e-06
# Epoch 26/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7706 - loss: 0.8104 - val_accuracy: 0.7959 - val_loss: 0.7729 - learning_rate: 1.0000e-06
# Epoch 27/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7753 - loss: 0.8043 - val_accuracy: 0.8063 - val_loss: 0.7367 - learning_rate: 1.0000e-06
# Epoch 28/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7669 - loss: 0.8168 - val_accuracy: 0.8133 - val_loss: 0.7123 - learning_rate: 1.0000e-06
# Epoch 29/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7892 - loss: 0.7756 - val_accuracy: 0.8154 - val_loss: 0.6956 - learning_rate: 1.0000e-06
# Epoch 30/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7770 - loss: 0.8198 - val_accuracy: 0.8190 - val_loss: 0.6832 - learning_rate: 1.0000e-06
# Epoch 31/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7799 - loss: 0.8011 - val_accuracy: 0.8199 - val_loss: 0.6746 - learning_rate: 1.0000e-06
# Epoch 32/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7747 - loss: 0.8043 - val_accuracy: 0.8187 - val_loss: 0.6692 - learning_rate: 1.0000e-06
# Epoch 33/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7926 - loss: 0.7657 - val_accuracy: 0.8188 - val_loss: 0.6642 - learning_rate: 1.0000e-06
# Epoch 34/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7851 - loss: 0.7785 - val_accuracy: 0.8202 - val_loss: 0.6609 - learning_rate: 1.0000e-06
# Epoch 35/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7802 - loss: 0.8039 - val_accuracy: 0.8205 - val_loss: 0.6592 - learning_rate: 1.0000e-06
# Epoch 36/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7612 - loss: 0.8032 - val_accuracy: 0.8202 - val_loss: 0.6567 - learning_rate: 1.0000e-06
# Epoch 37/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7831 - loss: 0.7740 - val_accuracy: 0.8202 - val_loss: 0.6548 - learning_rate: 1.0000e-06
# Epoch 38/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7935 - loss: 0.7773 - val_accuracy: 0.8202 - val_loss: 0.6534 - learning_rate: 1.0000e-06
# Epoch 39/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7889 - loss: 0.7688 - val_accuracy: 0.8201 - val_loss: 0.6525 - learning_rate: 1.0000e-06
# Epoch 40/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7868 - loss: 0.7783 - val_accuracy: 0.8202 - val_loss: 0.6509 - learning_rate: 1.0000e-06
# Epoch 41/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7902 - loss: 0.7833 - val_accuracy: 0.8198 - val_loss: 0.6498 - learning_rate: 1.0000e-06
# Epoch 42/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7883 - loss: 0.7800 - val_accuracy: 0.8208 - val_loss: 0.6485 - learning_rate: 1.0000e-06
# Epoch 43/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7840 - loss: 0.7866 - val_accuracy: 0.8199 - val_loss: 0.6474 - learning_rate: 1.0000e-06
# Epoch 44/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7775 - loss: 0.7869 - val_accuracy: 0.8204 - val_loss: 0.6470 - learning_rate: 1.0000e-06
# Epoch 45/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7848 - loss: 0.7644 - val_accuracy: 0.8213 - val_loss: 0.6462 - learning_rate: 1.0000e-06
# Epoch 46/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7811 - loss: 0.7906 - val_accuracy: 0.8204 - val_loss: 0.6457 - learning_rate: 1.0000e-06
# Epoch 47/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7850 - loss: 0.7789 - val_accuracy: 0.8208 - val_loss: 0.6450 - learning_rate: 1.0000e-06
# Epoch 48/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7796 - loss: 0.7950 - val_accuracy: 0.8205 - val_loss: 0.6438 - learning_rate: 1.0000e-06
# Epoch 49/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7798 - loss: 0.7831 - val_accuracy: 0.8211 - val_loss: 0.6433 - learning_rate: 1.0000e-06
# Epoch 50/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7892 - loss: 0.7698 - val_accuracy: 0.8219 - val_loss: 0.6419 - learning_rate: 1.0000e-06
# Epoch 51/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7892 - loss: 0.7603 - val_accuracy: 0.8211 - val_loss: 0.6413 - learning_rate: 1.0000e-06
# Epoch 52/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7783 - loss: 0.7878 - val_accuracy: 0.8224 - val_loss: 0.6408 - learning_rate: 1.0000e-06
# Epoch 53/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7742 - loss: 0.8033 - val_accuracy: 0.8228 - val_loss: 0.6395 - learning_rate: 1.0000e-06
# Epoch 54/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7956 - loss: 0.7604 - val_accuracy: 0.8228 - val_loss: 0.6386 - learning_rate: 1.0000e-06
# Epoch 55/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7907 - loss: 0.7635 - val_accuracy: 0.8213 - val_loss: 0.6384 - learning_rate: 1.0000e-06
# Epoch 56/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7866 - loss: 0.7652 - val_accuracy: 0.8218 - val_loss: 0.6380 - learning_rate: 1.0000e-06
# Epoch 57/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7812 - loss: 0.7801 - val_accuracy: 0.8225 - val_loss: 0.6376 - learning_rate: 1.0000e-06
# Epoch 58/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7820 - loss: 0.7938 - val_accuracy: 0.8221 - val_loss: 0.6368 - learning_rate: 1.0000e-06
# Epoch 59/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7870 - loss: 0.7600 - val_accuracy: 0.8224 - val_loss: 0.6357 - learning_rate: 1.0000e-06
# Epoch 60/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7946 - loss: 0.7623 - val_accuracy: 0.8230 - val_loss: 0.6345 - learning_rate: 1.0000e-06
# Epoch 61/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7892 - loss: 0.7705 - val_accuracy: 0.8238 - val_loss: 0.6339 - learning_rate: 1.0000e-06
# Epoch 62/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7935 - loss: 0.7614 - val_accuracy: 0.8250 - val_loss: 0.6328 - learning_rate: 1.0000e-06
# Epoch 63/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7908 - loss: 0.7644 - val_accuracy: 0.8245 - val_loss: 0.6323 - learning_rate: 1.0000e-06
# Epoch 64/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7918 - loss: 0.7621 - val_accuracy: 0.8253 - val_loss: 0.6313 - learning_rate: 1.0000e-06
# Epoch 65/65
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7941 - loss: 0.7544 - val_accuracy: 0.8238 - val_loss: 0.6315 - learning_rate: 1.0000e-06
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6765 - loss: 0.9885
# Test accuracy: 0.6770
# === Training on 25% of data ===
# Epoch 1/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 83ms/step - accuracy: 0.3034 - loss: 2.0624 - val_accuracy: 0.0495 - val_loss: 2.8970 - learning_rate: 1.0000e-04
# Epoch 2/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.6570 - loss: 1.1010 - val_accuracy: 0.0495 - val_loss: 4.4708 - learning_rate: 1.0000e-04
# Epoch 3/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7460 - loss: 0.8533 - val_accuracy: 0.0495 - val_loss: 5.5097 - learning_rate: 1.0000e-04
# Epoch 4/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8038 - loss: 0.6925 - val_accuracy: 0.0496 - val_loss: 5.2192 - learning_rate: 1.0000e-04
# Epoch 5/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8332 - loss: 0.5960 - val_accuracy: 0.0844 - val_loss: 4.7061 - learning_rate: 1.0000e-04
# Epoch 6/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8639 - loss: 0.5069
# Epoch 6: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8639 - loss: 0.5068 - val_accuracy: 0.1490 - val_loss: 4.2664 - learning_rate: 1.0000e-04
# Epoch 7/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8760 - loss: 0.4608 - val_accuracy: 0.2020 - val_loss: 3.2709 - learning_rate: 1.0000e-05
# Epoch 8/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8791 - loss: 0.4561 - val_accuracy: 0.2944 - val_loss: 2.0395 - learning_rate: 1.0000e-05
# Epoch 9/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8810 - loss: 0.4505 - val_accuracy: 0.7156 - val_loss: 0.9704 - learning_rate: 1.0000e-05
# Epoch 10/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8828 - loss: 0.4364 - val_accuracy: 0.8623 - val_loss: 0.5488 - learning_rate: 1.0000e-05
# Epoch 11/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8916 - loss: 0.4242 - val_accuracy: 0.8942 - val_loss: 0.4244 - learning_rate: 1.0000e-05
# Epoch 12/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8853 - loss: 0.4245 - val_accuracy: 0.9053 - val_loss: 0.3729 - learning_rate: 1.0000e-05
# Epoch 13/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8852 - loss: 0.4302 - val_accuracy: 0.9076 - val_loss: 0.3578 - learning_rate: 1.0000e-05
# Epoch 14/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8929 - loss: 0.4165 - val_accuracy: 0.9100 - val_loss: 0.3456 - learning_rate: 1.0000e-05
# Epoch 15/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8997 - loss: 0.4000 - val_accuracy: 0.9077 - val_loss: 0.3434 - learning_rate: 1.0000e-05
# Epoch 16/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8918 - loss: 0.4126 - val_accuracy: 0.9079 - val_loss: 0.3390 - learning_rate: 1.0000e-05
# Epoch 17/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8951 - loss: 0.4062 - val_accuracy: 0.9125 - val_loss: 0.3297 - learning_rate: 1.0000e-05
# Epoch 18/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9003 - loss: 0.3951 - val_accuracy: 0.9074 - val_loss: 0.3339 - learning_rate: 1.0000e-05
# Epoch 19/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8963 - loss: 0.3955 - val_accuracy: 0.9151 - val_loss: 0.3209 - learning_rate: 1.0000e-05
# Epoch 20/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9054 - loss: 0.3834 - val_accuracy: 0.9120 - val_loss: 0.3227 - learning_rate: 1.0000e-05
# Epoch 21/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9041 - loss: 0.3822 - val_accuracy: 0.9177 - val_loss: 0.3097 - learning_rate: 1.0000e-05
# Epoch 22/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9002 - loss: 0.3816 - val_accuracy: 0.9151 - val_loss: 0.3179 - learning_rate: 1.0000e-05
# Epoch 23/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8981 - loss: 0.3798 - val_accuracy: 0.9207 - val_loss: 0.3058 - learning_rate: 1.0000e-05
# Epoch 24/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9043 - loss: 0.3763 - val_accuracy: 0.9210 - val_loss: 0.3009 - learning_rate: 1.0000e-05
# Epoch 25/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9081 - loss: 0.3716 - val_accuracy: 0.9170 - val_loss: 0.3061 - learning_rate: 1.0000e-05
# Epoch 26/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9124 - loss: 0.3587 - val_accuracy: 0.9133 - val_loss: 0.3101 - learning_rate: 1.0000e-05
# Epoch 27/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9072 - loss: 0.3642 - val_accuracy: 0.9197 - val_loss: 0.3012 - learning_rate: 1.0000e-05
# Epoch 28/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9078 - loss: 0.3584 - val_accuracy: 0.9230 - val_loss: 0.2887 - learning_rate: 1.0000e-05
# Epoch 29/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9112 - loss: 0.3477 - val_accuracy: 0.9230 - val_loss: 0.2861 - learning_rate: 1.0000e-05
# Epoch 30/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9135 - loss: 0.3448 - val_accuracy: 0.9188 - val_loss: 0.2958 - learning_rate: 1.0000e-05
# Epoch 31/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9095 - loss: 0.3536 - val_accuracy: 0.9224 - val_loss: 0.2860 - learning_rate: 1.0000e-05
# Epoch 32/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9071 - loss: 0.3541 - val_accuracy: 0.9213 - val_loss: 0.2908 - learning_rate: 1.0000e-05
# Epoch 33/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9104 - loss: 0.3463 - val_accuracy: 0.9254 - val_loss: 0.2756 - learning_rate: 1.0000e-05
# Epoch 34/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9177 - loss: 0.3310 - val_accuracy: 0.9268 - val_loss: 0.2750 - learning_rate: 1.0000e-05
# Epoch 35/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9176 - loss: 0.3294 - val_accuracy: 0.9265 - val_loss: 0.2775 - learning_rate: 1.0000e-05
# Epoch 36/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9166 - loss: 0.3316 - val_accuracy: 0.9273 - val_loss: 0.2701 - learning_rate: 1.0000e-05
# Epoch 37/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9221 - loss: 0.3145 - val_accuracy: 0.9240 - val_loss: 0.2774 - learning_rate: 1.0000e-05
# Epoch 38/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9181 - loss: 0.3225 - val_accuracy: 0.9314 - val_loss: 0.2593 - learning_rate: 1.0000e-05
# Epoch 39/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9231 - loss: 0.3224 - val_accuracy: 0.9276 - val_loss: 0.2618 - learning_rate: 1.0000e-05
# Epoch 40/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9201 - loss: 0.3218 - val_accuracy: 0.9281 - val_loss: 0.2642 - learning_rate: 1.0000e-05
# Epoch 41/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9157 - loss: 0.3096 - val_accuracy: 0.9339 - val_loss: 0.2542 - learning_rate: 1.0000e-05
# Epoch 42/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9219 - loss: 0.3082 - val_accuracy: 0.9287 - val_loss: 0.2630 - learning_rate: 1.0000e-05
# Epoch 43/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9241 - loss: 0.3104 - val_accuracy: 0.9271 - val_loss: 0.2614 - learning_rate: 1.0000e-05
# Epoch 44/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9249 - loss: 0.3012 - val_accuracy: 0.9313 - val_loss: 0.2528 - learning_rate: 1.0000e-05
# Epoch 45/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9272 - loss: 0.2996 - val_accuracy: 0.9288 - val_loss: 0.2522 - learning_rate: 1.0000e-05
# Epoch 46/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9230 - loss: 0.3047 - val_accuracy: 0.9371 - val_loss: 0.2410 - learning_rate: 1.0000e-05
# Epoch 47/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9220 - loss: 0.3079 - val_accuracy: 0.9376 - val_loss: 0.2384 - learning_rate: 1.0000e-05
# Epoch 48/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9232 - loss: 0.2907 - val_accuracy: 0.9277 - val_loss: 0.2591 - learning_rate: 1.0000e-05
# Epoch 49/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9284 - loss: 0.2937 - val_accuracy: 0.9382 - val_loss: 0.2360 - learning_rate: 1.0000e-05
# Epoch 50/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9274 - loss: 0.2905 - val_accuracy: 0.9319 - val_loss: 0.2473 - learning_rate: 1.0000e-05
# Epoch 51/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9293 - loss: 0.2884 - val_accuracy: 0.9273 - val_loss: 0.2591 - learning_rate: 1.0000e-05
# Epoch 52/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9240 - loss: 0.2846 - val_accuracy: 0.9387 - val_loss: 0.2315 - learning_rate: 1.0000e-05
# Epoch 53/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9238 - loss: 0.2841 - val_accuracy: 0.9378 - val_loss: 0.2360 - learning_rate: 1.0000e-05
# Epoch 54/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9312 - loss: 0.2712 - val_accuracy: 0.9331 - val_loss: 0.2410 - learning_rate: 1.0000e-05
# Epoch 55/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9309 - loss: 0.2746 - val_accuracy: 0.9279 - val_loss: 0.2542 - learning_rate: 1.0000e-05
# Epoch 56/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9294 - loss: 0.2758 - val_accuracy: 0.9341 - val_loss: 0.2384 - learning_rate: 1.0000e-05
# Epoch 57/57
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9324 - loss: 0.2665
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1e-06.
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9324 - loss: 0.2665 - val_accuracy: 0.9338 - val_loss: 0.2358 - learning_rate: 1.0000e-05
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8526 - loss: 0.4815
# Test accuracy: 0.8500
# === Training on 50% of data ===
# Epoch 1/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.4160 - loss: 1.7240 - val_accuracy: 0.0495 - val_loss: 4.4838 - learning_rate: 1.0000e-04
# Epoch 2/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.7537 - loss: 0.8441 - val_accuracy: 0.0541 - val_loss: 6.1956 - learning_rate: 1.0000e-04
# Epoch 3/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8374 - loss: 0.5843 - val_accuracy: 0.1256 - val_loss: 4.0342 - learning_rate: 1.0000e-04
# Epoch 4/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8813 - loss: 0.4469 - val_accuracy: 0.4568 - val_loss: 1.3467 - learning_rate: 1.0000e-04
# Epoch 5/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8985 - loss: 0.3762 - val_accuracy: 0.9076 - val_loss: 0.3857 - learning_rate: 1.0000e-04
# Epoch 6/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9128 - loss: 0.3256 - val_accuracy: 0.9509 - val_loss: 0.2252 - learning_rate: 1.0000e-04
# Epoch 7/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9259 - loss: 0.2907 - val_accuracy: 0.9518 - val_loss: 0.2153 - learning_rate: 1.0000e-04
# Epoch 8/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9344 - loss: 0.2620 - val_accuracy: 0.9307 - val_loss: 0.2398 - learning_rate: 1.0000e-04
# Epoch 9/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9429 - loss: 0.2399 - val_accuracy: 0.9256 - val_loss: 0.2407 - learning_rate: 1.0000e-04
# Epoch 10/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9489 - loss: 0.2123 - val_accuracy: 0.9598 - val_loss: 0.1714 - learning_rate: 1.0000e-04
# Epoch 11/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9496 - loss: 0.2017 - val_accuracy: 0.9610 - val_loss: 0.1530 - learning_rate: 1.0000e-04
# Epoch 12/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9560 - loss: 0.1803 - val_accuracy: 0.9073 - val_loss: 0.2745 - learning_rate: 1.0000e-04
# Epoch 13/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9610 - loss: 0.1678 - val_accuracy: 0.9612 - val_loss: 0.1475 - learning_rate: 1.0000e-04
# Epoch 14/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9611 - loss: 0.1608 - val_accuracy: 0.9498 - val_loss: 0.1674 - learning_rate: 1.0000e-04
# Epoch 15/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9684 - loss: 0.1395 - val_accuracy: 0.9660 - val_loss: 0.1294 - learning_rate: 1.0000e-04
# Epoch 16/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9698 - loss: 0.1325 - val_accuracy: 0.9680 - val_loss: 0.1214 - learning_rate: 1.0000e-04
# Epoch 17/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9743 - loss: 0.1220 - val_accuracy: 0.9684 - val_loss: 0.1241 - learning_rate: 1.0000e-04
# Epoch 18/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9741 - loss: 0.1131 - val_accuracy: 0.9541 - val_loss: 0.1618 - learning_rate: 1.0000e-04
# Epoch 19/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9748 - loss: 0.1113 - val_accuracy: 0.9727 - val_loss: 0.1053 - learning_rate: 1.0000e-04
# Epoch 20/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9768 - loss: 0.1034 - val_accuracy: 0.9683 - val_loss: 0.1090 - learning_rate: 1.0000e-04
# Epoch 21/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9811 - loss: 0.0930 - val_accuracy: 0.9658 - val_loss: 0.1187 - learning_rate: 1.0000e-04
# Epoch 22/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9790 - loss: 0.0925 - val_accuracy: 0.9698 - val_loss: 0.1081 - learning_rate: 1.0000e-04
# Epoch 23/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9810 - loss: 0.0868 - val_accuracy: 0.9695 - val_loss: 0.1067 - learning_rate: 1.0000e-04
# Epoch 24/45
# 134/135 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9841 - loss: 0.0784
# Epoch 24: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9841 - loss: 0.0785 - val_accuracy: 0.9596 - val_loss: 0.1351 - learning_rate: 1.0000e-04
# Epoch 25/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9864 - loss: 0.0721 - val_accuracy: 0.9673 - val_loss: 0.1081 - learning_rate: 1.0000e-05
# Epoch 26/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9897 - loss: 0.0651 - val_accuracy: 0.9726 - val_loss: 0.0942 - learning_rate: 1.0000e-05
# Epoch 27/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9869 - loss: 0.0663 - val_accuracy: 0.9723 - val_loss: 0.0924 - learning_rate: 1.0000e-05
# Epoch 28/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9895 - loss: 0.0622 - val_accuracy: 0.9724 - val_loss: 0.0933 - learning_rate: 1.0000e-05
# Epoch 29/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9899 - loss: 0.0600 - val_accuracy: 0.9715 - val_loss: 0.0940 - learning_rate: 1.0000e-05
# Epoch 30/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9888 - loss: 0.0623 - val_accuracy: 0.9727 - val_loss: 0.0928 - learning_rate: 1.0000e-05
# Epoch 31/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9894 - loss: 0.0609 - val_accuracy: 0.9735 - val_loss: 0.0921 - learning_rate: 1.0000e-05
# Epoch 32/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9897 - loss: 0.0626 - val_accuracy: 0.9720 - val_loss: 0.0941 - learning_rate: 1.0000e-05
# Epoch 33/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9908 - loss: 0.0587 - val_accuracy: 0.9724 - val_loss: 0.0919 - learning_rate: 1.0000e-05
# Epoch 34/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9901 - loss: 0.0595 - val_accuracy: 0.9726 - val_loss: 0.0905 - learning_rate: 1.0000e-05
# Epoch 35/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9912 - loss: 0.0583 - val_accuracy: 0.9724 - val_loss: 0.0916 - learning_rate: 1.0000e-05
# Epoch 36/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9901 - loss: 0.0572 - val_accuracy: 0.9720 - val_loss: 0.0921 - learning_rate: 1.0000e-05
# Epoch 37/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9900 - loss: 0.0612 - val_accuracy: 0.9704 - val_loss: 0.1022 - learning_rate: 1.0000e-05
# Epoch 38/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9902 - loss: 0.0572 - val_accuracy: 0.9715 - val_loss: 0.0945 - learning_rate: 1.0000e-05
# Epoch 39/45
# 134/135 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9902 - loss: 0.0584
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1e-06.
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9902 - loss: 0.0584 - val_accuracy: 0.9715 - val_loss: 0.0913 - learning_rate: 1.0000e-05
# Epoch 40/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9903 - loss: 0.0561 - val_accuracy: 0.9720 - val_loss: 0.0924 - learning_rate: 1.0000e-06
# Epoch 41/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9929 - loss: 0.0562 - val_accuracy: 0.9721 - val_loss: 0.0915 - learning_rate: 1.0000e-06
# Epoch 42/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9913 - loss: 0.0547 - val_accuracy: 0.9718 - val_loss: 0.0925 - learning_rate: 1.0000e-06
# Epoch 43/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9916 - loss: 0.0577 - val_accuracy: 0.9721 - val_loss: 0.0924 - learning_rate: 1.0000e-06
# Epoch 44/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9919 - loss: 0.0556 - val_accuracy: 0.9721 - val_loss: 0.0926 - learning_rate: 1.0000e-06
# Epoch 45/45
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9925 - loss: 0.0521 - val_accuracy: 0.9721 - val_loss: 0.0931 - learning_rate: 1.0000e-06
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9180 - loss: 0.2632
# Test accuracy: 0.9153
# === Training on 75% of data ===
# Epoch 1/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 15s 41ms/step - accuracy: 0.4563 - loss: 1.6091 - val_accuracy: 0.0495 - val_loss: 4.9123 - learning_rate: 1.0000e-04
# Epoch 2/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8011 - loss: 0.7057 - val_accuracy: 0.1175 - val_loss: 3.7418 - learning_rate: 1.0000e-04
# Epoch 3/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8679 - loss: 0.4821 - val_accuracy: 0.7493 - val_loss: 0.8352 - learning_rate: 1.0000e-04
# Epoch 4/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8984 - loss: 0.3732 - val_accuracy: 0.9043 - val_loss: 0.3702 - learning_rate: 1.0000e-04
# Epoch 5/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9165 - loss: 0.3091 - val_accuracy: 0.9435 - val_loss: 0.2221 - learning_rate: 1.0000e-04
# Epoch 6/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9344 - loss: 0.2586 - val_accuracy: 0.9402 - val_loss: 0.2213 - learning_rate: 1.0000e-04
# Epoch 7/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9458 - loss: 0.2227 - val_accuracy: 0.9524 - val_loss: 0.1878 - learning_rate: 1.0000e-04
# Epoch 8/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9486 - loss: 0.2038 - val_accuracy: 0.9558 - val_loss: 0.1643 - learning_rate: 1.0000e-04
# Epoch 9/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.9586 - loss: 0.1738 - val_accuracy: 0.9458 - val_loss: 0.1785 - learning_rate: 1.0000e-04
# Epoch 10/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9624 - loss: 0.1594 - val_accuracy: 0.9598 - val_loss: 0.1426 - learning_rate: 1.0000e-04
# Epoch 11/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9636 - loss: 0.1416 - val_accuracy: 0.9601 - val_loss: 0.1390 - learning_rate: 1.0000e-04
# Epoch 12/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9682 - loss: 0.1287 - val_accuracy: 0.9669 - val_loss: 0.1199 - learning_rate: 1.0000e-04
# Epoch 13/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9744 - loss: 0.1126 - val_accuracy: 0.9626 - val_loss: 0.1232 - learning_rate: 1.0000e-04
# Epoch 14/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9770 - loss: 0.1033 - val_accuracy: 0.9544 - val_loss: 0.1535 - learning_rate: 1.0000e-04
# Epoch 15/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9781 - loss: 0.0961 - val_accuracy: 0.9382 - val_loss: 0.2044 - learning_rate: 1.0000e-04
# Epoch 16/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.9811 - loss: 0.0883 - val_accuracy: 0.9612 - val_loss: 0.1188 - learning_rate: 1.0000e-04
# Epoch 17/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9835 - loss: 0.0791 - val_accuracy: 0.9567 - val_loss: 0.1308 - learning_rate: 1.0000e-04
# Epoch 18/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9842 - loss: 0.0751 - val_accuracy: 0.9430 - val_loss: 0.1622 - learning_rate: 1.0000e-04
# Epoch 19/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9857 - loss: 0.0681 - val_accuracy: 0.9666 - val_loss: 0.0989 - learning_rate: 1.0000e-04
# Epoch 20/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9860 - loss: 0.0658 - val_accuracy: 0.9670 - val_loss: 0.1023 - learning_rate: 1.0000e-04
# Epoch 21/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9861 - loss: 0.0637 - val_accuracy: 0.9698 - val_loss: 0.0942 - learning_rate: 1.0000e-04
# Epoch 22/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9901 - loss: 0.0505 - val_accuracy: 0.9601 - val_loss: 0.1160 - learning_rate: 1.0000e-04
# Epoch 23/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.9898 - loss: 0.0519 - val_accuracy: 0.9630 - val_loss: 0.1213 - learning_rate: 1.0000e-04
# Epoch 24/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9893 - loss: 0.0512 - val_accuracy: 0.9693 - val_loss: 0.0934 - learning_rate: 1.0000e-04
# Epoch 25/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9925 - loss: 0.0428 - val_accuracy: 0.9606 - val_loss: 0.1168 - learning_rate: 1.0000e-04
# Epoch 26/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9917 - loss: 0.0445 - val_accuracy: 0.9627 - val_loss: 0.1041 - learning_rate: 1.0000e-04
# Epoch 27/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9931 - loss: 0.0381 - val_accuracy: 0.9592 - val_loss: 0.1234 - learning_rate: 1.0000e-04
# Epoch 28/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9939 - loss: 0.0351 - val_accuracy: 0.9684 - val_loss: 0.0937 - learning_rate: 1.0000e-04
# Epoch 29/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9937 - loss: 0.0332
# Epoch 29: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9937 - loss: 0.0332 - val_accuracy: 0.9683 - val_loss: 0.1033 - learning_rate: 1.0000e-04
# Epoch 30/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9948 - loss: 0.0294 - val_accuracy: 0.9746 - val_loss: 0.0717 - learning_rate: 1.0000e-05
# Epoch 31/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9975 - loss: 0.0229 - val_accuracy: 0.9760 - val_loss: 0.0691 - learning_rate: 1.0000e-05
# Epoch 32/32
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.9971 - loss: 0.0230 - val_accuracy: 0.9757 - val_loss: 0.0693 - learning_rate: 1.0000e-05
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9279 - loss: 0.2227
# Test accuracy: 0.9263
# === Training on 100% of data ===
# Epoch 1/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 16s 35ms/step - accuracy: 0.4916 - loss: 1.5128 - val_accuracy: 0.0521 - val_loss: 5.9818 - learning_rate: 1.0000e-04
# Epoch 2/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.8420 - loss: 0.5862 - val_accuracy: 0.2862 - val_loss: 2.2466 - learning_rate: 1.0000e-04
# Epoch 3/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.8986 - loss: 0.3901 - val_accuracy: 0.9219 - val_loss: 0.2856 - learning_rate: 1.0000e-04
# Epoch 4/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9218 - loss: 0.3079 - val_accuracy: 0.9461 - val_loss: 0.2073 - learning_rate: 1.0000e-04
# Epoch 5/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9366 - loss: 0.2516 - val_accuracy: 0.9264 - val_loss: 0.2272 - learning_rate: 1.0000e-04
# Epoch 6/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9438 - loss: 0.2191 - val_accuracy: 0.9447 - val_loss: 0.2030 - learning_rate: 1.0000e-04
# Epoch 7/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9538 - loss: 0.1851 - val_accuracy: 0.9524 - val_loss: 0.1704 - learning_rate: 1.0000e-04
# Epoch 8/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9597 - loss: 0.1655 - val_accuracy: 0.9390 - val_loss: 0.2385 - learning_rate: 1.0000e-04
# Epoch 9/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9643 - loss: 0.1497 - val_accuracy: 0.9316 - val_loss: 0.2116 - learning_rate: 1.0000e-04
# Epoch 10/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9671 - loss: 0.1352 - val_accuracy: 0.9599 - val_loss: 0.1308 - learning_rate: 1.0000e-04
# Epoch 11/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9729 - loss: 0.1158 - val_accuracy: 0.9627 - val_loss: 0.1286 - learning_rate: 1.0000e-04
# Epoch 12/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9754 - loss: 0.1072 - val_accuracy: 0.9690 - val_loss: 0.1074 - learning_rate: 1.0000e-04
# Epoch 13/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9755 - loss: 0.1056 - val_accuracy: 0.9627 - val_loss: 0.1281 - learning_rate: 1.0000e-04
# Epoch 14/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9781 - loss: 0.0927 - val_accuracy: 0.9549 - val_loss: 0.1445 - learning_rate: 1.0000e-04
# Epoch 15/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9788 - loss: 0.0884 - val_accuracy: 0.9559 - val_loss: 0.1465 - learning_rate: 1.0000e-04
# Epoch 16/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9810 - loss: 0.0843 - val_accuracy: 0.9712 - val_loss: 0.0938 - learning_rate: 1.0000e-04
# Epoch 17/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9835 - loss: 0.0744 - val_accuracy: 0.9570 - val_loss: 0.1351 - learning_rate: 1.0000e-04
# Epoch 18/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9844 - loss: 0.0677 - val_accuracy: 0.9697 - val_loss: 0.1031 - learning_rate: 1.0000e-04
# Epoch 19/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9871 - loss: 0.0616 - val_accuracy: 0.9462 - val_loss: 0.1642 - learning_rate: 1.0000e-04
# Epoch 20/20
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.9866 - loss: 0.0608 - val_accuracy: 0.9758 - val_loss: 0.0811 - learning_rate: 1.0000e-04
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9272 - loss: 0.2342
# Test accuracy: 0.9260
# Plot has been saved as accuracy_vs_data_size.png
# means:  [np.float64(0.5041624307632446), np.float64(0.5582742691040039), np.float64(0.67701655626297), np.float64(0.8500393629074097), np.float64(0.9152885675430298), np.float64(0.9262571930885315), np.float64(0.9260321855545044)]
# stds:  [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# [np.float64(0.5041624307632446), np.float64(0.5582742691040039), np.float64(0.67701655626297), np.float64(0.8500393629074097), np.float64(0.9152885675430298), np.float64(0.9262571930885315), np.float64(0.9260321855545044)]

# %%
percentages = [int(size * 100) for size in sizes]

plt.figure(figsize=(6, 4))
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, elinewidth=2)

for x, y in zip(percentages, means):
    plt.text(x + 5, y + 0.01, f"{y:.3f}", ha='center', fontsize=10, color='black')
    
#plt.title("Accuracy vs Data Size", fontsize=18)
plt.xlabel("Percentage of data used [%]", fontsize=18)
plt.ylabel("Accuracy - test", fontsize=18)
plt.ylim((0,1.0)) 
plt.xlim((0,105))
plt.grid(True)
plt.tight_layout()
plt.savefig('accuracy_vs_data_size_OrganAMNIST_2.png')
print('Plot has been saved as accuracy_vs_data_size.png')
plt.show()

print("means: ", means)
print("stds: ", stds)
# Out:
# Plot has been saved as accuracy_vs_data_size.png
# means:  [np.float64(0.5041624307632446), np.float64(0.5582742691040039), np.float64(0.67701655626297), np.float64(0.8500393629074097), np.float64(0.9152885675430298), np.float64(0.9262571930885315), np.float64(0.9260321855545044)]
# stds:  [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]

# %%
def split_subset_and_rest(X, y, subset_size: int):
    total_size = len(X)

    indices = np.arange(total_size)
    np.random.shuffle(indices)

    subset_indices = indices[:subset_size]
    rest_indices = indices[subset_size:]

    X_subset = X[subset_indices]
    y_subset = y[subset_indices]

    X_rest = X[rest_indices]
    y_rest = y[rest_indices]

    return X_subset, y_subset, X_rest, y_rest

# %%
subset_size = len(X_train) * 0.1
epochs = 100
X_train_subset, y_train_subset, X_train_rest, y_train_rest = split_subset_and_rest(X_train, y_train, int(subset_size))
X_val_subset, y_val_subset, X_val_rest, y_val_rest = split_subset_and_rest(X_val, y_val, int(subset_size))
X_test_subset, y_test_subset, X_test_rest, y_test_rest = split_subset_and_rest(X_test, y_test, int(subset_size))

print('X_train_subset shape:', X_train_subset.shape)
print('y_train_subset shape:', y_train_subset.shape)
print('X_val_subset shape:', X_val_subset.shape)
print('y_val_subset shape:', y_val_subset.shape)
print('X_test_subset shape:', X_test_subset.shape)
print('y_test_subset shape:', y_test_subset.shape)

model_10_v1 = ResNet18()

# Callbacks
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5, 
    patience=10, 
    min_lr=1e-6,
    verbose = True
)

#lr_schedule = callbacks.LearningRateScheduler(lambda epoch, lr: lr * 0.1 if epoch in [50, 75] else lr)

early_stopping = callbacks.EarlyStopping(
    monitor='val_accuracy', 
    patience=40, 
    restore_best_weights=True
)

history = model_10_v1.fit(X_train_subset, y_train_subset, 
                    epochs=epochs, 
                    batch_size=128, 
                    validation_data=(X_val_subset, y_val_subset), 
                    callbacks = [early_stopping,reduce_lr],
                    verbose = True
                   ) 

test_loss, test_acc = model_10_v1.evaluate(X_test_subset, y_test_subset)
# Out:
# [3038 7169 6883 ... 7657 3077 3768]
# [10371  7257  4394 ...  9259  1356  7202]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[151], line 5
#       3 epochs = 100
#       4 X_train_subset, y_train_subset, X_train_rest, y_train_rest = split_subset_and_rest(X_train, y_train, int(subset_size), int(total_size))
# ----> 5 X_val_subset, y_val_subset, X_val_rest, y_val_rest = split_subset_and_rest(X_val, y_val, int(subset_size), int(total_size))
#       6 X_test_subset, y_test_subset, X_test_rest, y_test_rest = split_subset_and_rest(X_test, y_test, int(subset_size), int(total_size))
#       8 print('X_train_subset shape:', X_train_subset.shape)
#
# Cell In[150], line 9, in split_subset_and_rest(X, y, subset_size, total_size)
#       6 subset_indices = indices[:subset_size]
#       7 rest_indices = indices[subset_size:]
# ----> 9 X_subset = X[subset_indices]
#      10 y_subset = y[subset_indices]
#      12 X_rest = X[rest_indices]
#
# IndexError: index 10371 is out of bounds for axis 0 with size 1712

# %%
import matplotlib.pyplot as plt

# Historia treningu
history_dict = history.history
train_accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(train_accuracy) + 1)

# Accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_accuracy, label='Train Accuracy')
plt.plot(epochs, val_accuracy, label='Val Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, train_loss, label='Train Loss')
plt.plot(epochs, val_loss, label='Val Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
y_true = np.argmax(y_test_subset, axis=1)
y_probs = model_10_v1.predict(X_test_subset) 
for i in range(20):
    print(f"Próbka {i}: {y_probs[i]}")

num_classes = y_probs.shape[1]

plt.figure(figsize=(10, 7))

for i in range(num_classes):
    # Dla klasy i: binary ground truth (1 dla klasy i, 0 dla innych)
    y_true_binary = (y_true == i).astype(int)
    y_score = y_probs[:, i]  # prawdopodobieństwa dla klasy i

    precision, recall, _ = precision_recall_curve(y_true_binary, y_score)

    plt.plot(recall, precision, label=f"Klasa {i}")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve (dla każdej klasy)")
plt.legend()
plt.grid()
plt.show()
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Próbka 0: [5.3868670e-04 6.7462242e-04 8.8564806e-02 2.3406125e-03 7.1888105e-03
#  2.1911506e-04 1.4201089e-02 8.8627231e-01]
# Próbka 1: [5.6931913e-05 1.1564462e-04 2.5019107e-02 8.1452180e-04 7.0268719e-04
#  1.9918898e-05 1.2799705e-03 9.7199112e-01]
# Próbka 2: [0.05948864 0.018787   0.05311282 0.20339537 0.04366559 0.20971474
#  0.38690254 0.02493333]
# Próbka 3: [3.0948893e-05 9.9978030e-01 1.8547911e-05 9.2137532e-05 1.0759284e-05
#  5.9195963e-06 3.8254664e-05 2.3047745e-05]
# Próbka 4: [0.01049466 0.00356861 0.52544343 0.3211432  0.05981244 0.06387527
#  0.01011454 0.00554778]
# Próbka 5: [2.7046828e-03 1.0886673e-03 4.3936705e-04 1.2896283e-04 5.7292031e-03
#  1.6663100e-03 9.8794782e-01 2.9482154e-04]
# Próbka 6: [1.5141376e-03 9.9244153e-01 3.2935382e-04 2.6176115e-03 2.6853071e-04
#  2.5445005e-04 1.5032231e-03 1.0711062e-03]
# Próbka 7: [5.3139282e-03 2.8731194e-03 8.2067735e-03 1.0420064e-03 2.8914247e-02
#  5.7288660e-03 9.4716024e-01 7.6081819e-04]
# Próbka 8: [0.00111384 0.00210995 0.5964437  0.01427791 0.02836947 0.0017131
#  0.02945527 0.32651675]
# Próbka 9: [0.0185253  0.00673622 0.00490178 0.44337386 0.00269739 0.51660645
#  0.00355666 0.00360237]
# Próbka 10: [1.2663098e-03 9.9322730e-01 3.0780144e-04 2.6263946e-03 3.1239766e-04
#  4.5327321e-04 1.4052870e-03 4.0124802e-04]
# Próbka 11: [0.10001758 0.01167507 0.03311269 0.71021754 0.02409064 0.11594743
#  0.00138383 0.00355519]
# Próbka 12: [7.4850011e-04 5.5907964e-04 1.1584038e-04 4.4253225e-05 1.4529676e-03
#  7.2612771e-04 9.9625528e-01 9.8004763e-05]
# Próbka 13: [5.0633081e-04 9.9794453e-01 3.6216370e-05 4.4358963e-05 1.2850022e-04
#  3.0926141e-05 1.2444119e-03 6.4708314e-05]
# Próbka 14: [0.01863274 0.02288475 0.00948152 0.00524316 0.0284201  0.01011166
#  0.8993053  0.00592088]
# Próbka 15: [0.02678087 0.01874106 0.10991479 0.64973843 0.03292494 0.14699726
#  0.00889233 0.00601032]
# Próbka 16: [0.09288867 0.01043962 0.31697336 0.06915879 0.4572945  0.03339607
#  0.01278413 0.00706496]
# Próbka 17: [0.02093861 0.82995063 0.01723714 0.02376357 0.02716975 0.00827561
#  0.06591006 0.0067546 ]
# Próbka 18: [0.3821267  0.03114382 0.05978452 0.06449586 0.3893056  0.06884252
#  0.00390962 0.00039143]
# Próbka 19: [0.10932349 0.08766215 0.03091987 0.60236907 0.03045142 0.1122271
#  0.01624556 0.0108014 ]

# %%
from sklearn.metrics import precision_recall_curve, f1_score

def find_best_thresholds_per_class(y_true, y_probs):
    num_classes = y_probs.shape[1]
    thresholds = []
    best_f1s = []

    for i in range(num_classes):
        y_true_binary = (y_true == i).astype(int)
        y_score = y_probs[:, i]

        precision, recall, thresh = precision_recall_curve(y_true_binary, y_score)
        f1 = 2 * (precision * recall) / (precision + recall + 1e-8)

        max_f1_idx = np.argmax(f1)
        best_thresh = thresh[max_f1_idx] if max_f1_idx < len(thresh) else 1.0

        thresholds.append(best_thresh)
        best_f1s.append(f1[max_f1_idx])

        print(f"Class {i} → The best threshold: {best_thresh:.2f}, F1-score: {f1[max_f1_idx]:.3f}")

    return thresholds, best_f1s
    
#y_true_labels = np.argmax(y_true, axis=1)  # jeśli masz one-hot
class_thresholds, class_f1s = find_best_thresholds_per_class(y_true, y_probs)
# Out:
# Class 0 → The best threshold: 0.32, F1-score: 0.748
# Class 1 → The best threshold: 0.28, F1-score: 0.958
# Class 2 → The best threshold: 0.50, F1-score: 0.862
# Class 3 → The best threshold: 0.36, F1-score: 0.692
# Class 4 → The best threshold: 0.23, F1-score: 0.784
# Class 5 → The best threshold: 0.32, F1-score: 0.753
# Class 6 → The best threshold: 0.50, F1-score: 0.946
# Class 7 → The best threshold: 0.49, F1-score: 0.988

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import precision_recall_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from scipy.stats import entropy

class SelfTrainingModel:
    def __init__(self, model_NN, num_classes, initial_ratio = 0.05, threshold_strategy = 'f1', batch_size = 128, min_epochs=35, max_epochs=80):
        self.model_NN = model_NN
        self.num_classes = num_classes
        self.initial_ratio = initial_ratio
        self.threshold_strategy = threshold_strategy
        self.batch_size = batch_size
        self.min_epochs = min_epochs
        self.max_epochs = max_epochs
        self.thresholds = None

        np.random.seed(42)
        tf.random.set_seed(42)

    def split_subset_and_rest(self, X, y, subset_size):
        total_size = len(X)
        indices = np.random.permutation(total_size)
        subset_idx, rest_idx = indices[:subset_size], indices[subset_size:]

        return X[subset_idx], y[subset_idx], X[rest_idx], y[rest_idx]

    def initial_balanced_split(self, X, y, subset_size):
        y_classes = np.argmax(y, axis=1)
        samples_per_class = subset_size // self.num_classes
        selected_indices = []
    
        for cls in range(self.num_classes):
            cls_indices = np.where(y_classes == cls)[0]
            if len(cls_indices) < samples_per_class:
                raise ValueError(f"Not enough samples for class {cls} to create balanced subset.")
            np.random.shuffle(cls_indices)
            selected_indices.extend(cls_indices[:samples_per_class])
    
        selected_indices = np.array(selected_indices)
        rest_indices = np.setdiff1d(np.arange(len(X)), selected_indices)

        for cls in range(self.num_classes):
            selected_class_count = np.sum(y_classes[selected_indices] == cls)
            rest_class_count = np.sum(y_classes[rest_indices] == cls)
            print(f"After split, Class {cls}: {selected_class_count} in subset, {rest_class_count} in the rest.")
    
        return X[selected_indices], y[selected_indices], X[rest_indices], y[rest_indices]

    
    def find_best_thresholds_per_class(self, y_true, y_probs):
        thresholds = []
        for i in range(self.num_classes):
            y_true_binary = (y_true == i).astype(int)
            y_score = y_probs[:, i]
            precision, recall, thresh = precision_recall_curve(y_true_binary, y_score)
            f1 = 2 * (precision * recall) / (precision + recall + 1e-8)
            max_f1_idx = np.argmax(f1)
            best_thresh = thresh[max_f1_idx] if max_f1_idx < len(thresh) else 1.0
            thresholds.append(best_thresh)
        #thresholds = np.clip(thresholds, 0.3, 0.8)
        print("Best thresholds ", thresholds)
        return thresholds
        

    def pseudo_label(self, model, X_unlabeled):
        y_probability = model.predict(X_unlabeled)
        X_confident, y_confident, X_unconfident = [], [], []
        #for i, probs in enumerate(y_probability[:10]):
        #    print(f"Sample {i}: {probs}")
        
        '''
        for i, probability in enumerate(y_probability):
            above_threshold = probability >= self.thresholds
            if np.any(above_threshold):
                pred_class = np.argmax(probability * above_threshold)
                X_confident.append(X_unlabeled[i])
                y_confident.append(tf.keras.utils.to_categorical(pred_class, num_classes=self.num_classes))
            else:
                X_unconfident.append(X_unlabeled[i])
        '''
        '''
        for i, probability in enumerate(y_probability):
            pred_class = np.argmax(probability)
            if probability[pred_class] >= self.thresholds[pred_class]:
                X_confident.append(X_unlabeled[i])
                y_confident.append(tf.keras.utils.to_categorical(pred_class, num_classes=self.num_classes))
            else:
                X_unconfident.append(X_unlabeled[i])
        '''

        for i, probs in enumerate(y_probability):
            ent = entropy(probs)
            if ent < 1.0:  # entropia niska -> wysoka pewność
                pred_class = np.argmax(probs)
                if probs[pred_class] >= self.thresholds[pred_class]:
                    X_confident.append(X_unlabeled[i])
                    y_confident.append(tf.keras.utils.to_categorical(pred_class, num_classes=self.num_classes))
                else:
                    X_unconfident.append(X_unlabeled[i])
            else:
                X_unconfident.append(X_unlabeled[i])

        return np.array(X_confident), np.array(y_confident), np.array(X_unconfident)

    def calculate_epochs(self, size):
        return int(self.min_epochs + (self.max_epochs - self.min_epochs) * (1 - size))

    def train(self, X_train, y_train, X_val, y_val):
        subset_size = int(len(X_train) * self.initial_ratio)
        #X_labeled, y_labeled, X_unlabeled, y_unlabeled = self.split_subset_and_rest(X_train, y_train, subset_size)
        X_labeled, y_labeled, X_unlabeled, y_unlabeled = self.initial_balanced_split(X_train, y_train, subset_size)
        
        print("X_labeled shape :", X_labeled.shape)
        print("X_unlabeled shape :", X_unlabeled.shape)

        round_num = 1
        while len(X_unlabeled) > 100:
            print(f"\n=== Iteration {round_num}: Training on {len(X_labeled)} labeled samples ===")

            y_labeled_classes = np.argmax(y_labeled, axis=1) 
            class_weights_array = compute_class_weight(class_weight='balanced',
                                                       classes=np.arange(self.num_classes),
                                                       y=y_labeled_classes)
            class_weights = dict(enumerate(class_weights_array))
            print("Class weights:", class_weights)
        
            reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                                          factor=0.1, 
                                          patience=5, 
                                          min_lr=1e-6,
                                          verbose = False
                                          )
        
            used_ratio = len(X_labeled) / len(X_train)
            no_of_epochs = self.calculate_epochs(used_ratio)
            print(no_of_epochs)

            model = self.model_NN()
            history = model.fit(X_labeled, y_labeled,
                                  epochs=no_of_epochs,
                                  batch_size=self.batch_size,
                                  validation_data=(X_val, y_val),
                                  callbacks=[reduce_lr],
                                  class_weight=class_weights,
                                  verbose=False)

            val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=0)
            print(f"=== Validation accuracy after iteration {round_num}: {val_accuracy:.4f} ===")

            y_val_labels = np.argmax(y_val, axis=1)
            y_probs = model.predict(X_val)
            self.thresholds = self.find_best_thresholds_per_class(y_val_labels, y_probs)

            
            if len(X_unlabeled) < int(len(X_train) * self.initial_ratio):
                current_subset_size = len(X_unlabeled)
            else:
                current_subset_size = int(len(X_train) * self.initial_ratio)

            X_subset, _, X_unlabeled, _ = self.split_subset_and_rest(X_unlabeled, y_unlabeled, current_subset_size)

            
            X_confident, y_confident, X_remaining = self.pseudo_label(model, X_subset)
            print(f"=== Added {len(X_confident)} confident samples, {len(X_subset) - len(X_confident)} remain unlabeled. ===")

            if len(X_confident) > 0:
                X_labeled = np.concatenate([X_labeled, X_confident], axis=0)
                y_labeled = np.concatenate([y_labeled, y_confident], axis=0)
            if len(X_remaining) > 0:
                X_unlabeled = np.concatenate([X_unlabeled, X_remaining], axis=0)

            round_num += 1

        print("Training completed")
        return model

# %%
trainer = SelfTrainingModel(model_NN=ResNet18, num_classes=8, initial_ratio=0.25, min_epochs=35, max_epochs=70)
final_model = trainer.train(X_train, y_train, X_val, y_val)
# Out:
# After split, Class 0: 373 in subset, 479 in the rest.
# After split, Class 1: 373 in subset, 1808 in the rest.
# After split, Class 2: 373 in subset, 712 in the rest.
# After split, Class 3: 373 in subset, 1653 in the rest.
# After split, Class 4: 373 in subset, 476 in the rest.
# After split, Class 5: 373 in subset, 620 in the rest.
# After split, Class 6: 373 in subset, 1957 in the rest.
# After split, Class 7: 373 in subset, 1270 in the rest.
# X_labeled shape : (2984, 28, 28, 3)
# X_unlabeled shape : (8975, 28, 28, 3)
#
# === Iteration 1: Training on 2984 labeled samples ===
# Class weights: {0: np.float64(1.0), 1: np.float64(1.0), 2: np.float64(1.0), 3: np.float64(1.0), 4: np.float64(1.0), 5: np.float64(1.0), 6: np.float64(1.0), 7: np.float64(1.0)}
# 60
# === Validation accuracy after iteration 1: 0.8475 ===
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [np.float32(0.3474998), np.float32(0.20086582), np.float32(0.44251794), np.float32(0.18337896), np.float32(0.36532992), np.float32(0.42925858), np.float32(0.34960207), np.float32(0.52431136)]
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# === Added 1742 confident samples, 1247 remain unlabeled. ===
#
# === Iteration 2: Training on 4726 labeled samples ===
# Class weights: {0: np.float64(1.3127777777777778), 1: np.float64(0.7248466257668712), 2: np.float64(1.1382466281310213), 3: np.float64(1.3834894613583137), 4: np.float64(1.3245515695067265), 5: np.float64(1.1628937007874016), 6: np.float64(0.77832674571805), 7: np.float64(0.7365960099750624)}
# 54
# === Validation accuracy after iteration 2: 0.8598 ===
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [np.float32(0.38532394), np.float32(0.18159823), np.float32(0.45821565), np.float32(0.19093671), np.float32(0.3593524), np.float32(0.3463791), np.float32(0.2899302), np.float32(0.5826964)]
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# === Added 1825 confident samples, 1164 remain unlabeled. ===
#
# === Iteration 3: Training on 6551 labeled samples ===
# Class weights: {0: np.float64(1.5220724907063197), 1: np.float64(0.6745263591433278), 2: np.float64(1.1582390381895333), 3: np.float64(1.550899621212121), 4: np.float64(1.4861615245009074), 5: np.float64(1.2875393081761006), 6: np.float64(0.6652112103980503), 7: np.float64(0.7145506108202443)}
# 48
# === Validation accuracy after iteration 3: 0.8779 ===
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [np.float32(0.44145197), np.float32(0.18155847), np.float32(0.48976073), np.float32(0.21509613), np.float32(0.5152494), np.float32(0.5569992), np.float32(0.26729915), np.float32(0.35607016)]
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# === Added 2041 confident samples, 948 remain unlabeled. ===
#
# === Iteration 4: Training on 8592 labeled samples ===
# Class weights: {0: np.float64(1.6029850746268657), 1: np.float64(0.6465984346779049), 2: np.float64(1.2576112412177987), 3: np.float64(1.356060606060606), 4: np.float64(1.5126760563380282), 5: np.float64(1.3177914110429447), 6: np.float64(0.6389054134443783), 7: np.float64(0.7622427253371186)}
# 41
# === Validation accuracy after iteration 4: 0.8884 ===
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [np.float32(0.56685454), np.float32(0.4209539), np.float32(0.6425727), np.float32(0.16636355), np.float32(0.47318092), np.float32(0.39273262), np.float32(0.39085782), np.float32(0.61775625)]
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# === Added 1808 confident samples, 1181 remain unlabeled. ===
#
# === Iteration 5: Training on 10400 labeled samples ===
# Class weights: {0: np.float64(1.6927083333333333), 1: np.float64(0.6429277942631059), 2: np.float64(1.311806256306761), 3: np.float64(1.146384479717813), 4: np.float64(1.5133876600698486), 5: np.float64(1.3157894736842106), 6: np.float64(0.6372549019607843), 7: np.float64(0.8135168961201502)}
# 35
# === Validation accuracy after iteration 5: 0.8902 ===
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [np.float32(0.42504779), np.float32(0.3536248), np.float32(0.38023812), np.float32(0.27665162), np.float32(0.6086768), np.float32(0.66172165), np.float32(0.37891665), np.float32(0.28036538)]
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# === Added 617 confident samples, 942 remain unlabeled. ===
#
# === Iteration 6: Training on 11017 labeled samples ===
# Class weights: {0: np.float64(1.6611881785283473), 1: np.float64(0.6636746987951807), 2: np.float64(1.3435365853658536), 3: np.float64(0.9900251617541337), 4: np.float64(1.5233683628318584), 5: np.float64(1.3448486328125), 6: np.float64(0.6441183348924229), 7: np.float64(0.8443439607602697)}
# 33
# === Validation accuracy after iteration 6: 0.9042 ===
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [np.float32(0.3680418), np.float32(0.4695844), np.float32(0.5932486), np.float32(0.059248958), np.float32(0.9050391), np.float32(0.9414334), np.float32(0.4283289), np.float32(0.27220458)]
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# === Added 397 confident samples, 545 remain unlabeled. ===
#
# === Iteration 7: Training on 11414 labeled samples ===
# Class weights: {0: np.float64(1.6667640186915889), 1: np.float64(0.6654617537313433), 2: np.float64(1.3745183044315992), 3: np.float64(0.9151699807568955), 4: np.float64(1.5695819581958195), 5: np.float64(1.3758437801350047), 6: np.float64(0.6377961555654895), 7: np.float64(0.8731640146878825)}
# 31
# === Validation accuracy after iteration 7: 0.9089 ===
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [np.float32(0.68581325), np.float32(0.39905325), np.float32(0.40614638), np.float32(0.10969724), np.float32(0.89853877), np.float32(0.7023481), np.float32(0.44603097), np.float32(0.25172254)]
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# === Added 177 confident samples, 368 remain unlabeled. ===
#
# === Iteration 8: Training on 11591 labeled samples ===
# Class weights: {0: np.float64(1.6464488636363637), 1: np.float64(0.6723317865429235), 2: np.float64(1.3904750479846448), 3: np.float64(0.8971362229102167), 4: np.float64(1.5869386637458927), 5: np.float64(1.341550925925926), 6: np.float64(0.6377090669014085), 7: np.float64(0.8867044063647491)}
# 31
# === Validation accuracy after iteration 8: 0.9124 ===
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [np.float32(0.6024663), np.float32(0.2894551), np.float32(0.4840259), np.float32(0.24333379), np.float32(0.47183314), np.float32(0.44818276), np.float32(0.41730413), np.float32(0.42273957)]
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# === Added 91 confident samples, 277 remain unlabeled. ===
#
# === Iteration 9: Training on 11682 labeled samples ===
# Class weights: {0: np.float64(1.6333892617449663), 1: np.float64(0.6769819193324061), 2: np.float64(1.3960325047801148), 3: np.float64(0.8817934782608695), 4: np.float64(1.5872282608695651), 5: np.float64(1.332344890510949), 6: np.float64(0.6407415533128565), 7: np.float64(0.8936658506731946)}
# 30
# === Validation accuracy after iteration 9: 0.9136 ===
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [np.float32(0.41748765), np.float32(0.6451135), np.float32(0.5345277), np.float32(0.18646698), np.float32(0.78606975), np.float32(0.5583464), np.float32(0.31237593), np.float32(0.3818931)]
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step
# === Added 42 confident samples, 235 remain unlabeled. ===
#
# === Iteration 10: Training on 11724 labeled samples ===
# Class weights: {0: np.float64(1.6247228381374723), 1: np.float64(0.6787864752200092), 2: np.float64(1.3997134670487106), 3: np.float64(0.8764952153110048), 4: np.float64(1.5843243243243244), 5: np.float64(1.3310626702997275), 6: np.float64(0.6416374781085814), 7: np.float64(0.8968788249694002)}
# 30
# === Validation accuracy after iteration 10: 0.8919 ===
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [np.float32(0.25281408), np.float32(0.2942465), np.float32(0.7580963), np.float32(0.22955763), np.float32(0.93455815), np.float32(0.7651756), np.float32(0.18962492), np.float32(0.5279172)]
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# === Added 37 confident samples, 198 remain unlabeled. ===
#
# === Iteration 11: Training on 11761 labeled samples ===
# Class weights: {0: np.float64(1.6262444690265487), 1: np.float64(0.6809286706808708), 2: np.float64(1.4014537654909438), 3: np.float64(0.8683549911399882), 4: np.float64(1.5790816326530612), 5: np.float64(1.3292269439421338), 6: np.float64(0.6436624343257443), 7: np.float64(0.8991590214067279)}
# 30
# === Validation accuracy after iteration 11: 0.9095 ===
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [np.float32(0.6668455), np.float32(0.19854589), np.float32(0.5826536), np.float32(0.15108202), np.float32(0.40107518), np.float32(0.65109575), np.float32(0.4391441), np.float32(0.3271017)]
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step
# === Added 34 confident samples, 164 remain unlabeled. ===
#
# === Iteration 12: Training on 11795 labeled samples ===
# Class weights: {0: np.float64(1.6043253536452666), 1: np.float64(0.6825810185185185), 2: np.float64(1.4055052430886559), 3: np.float64(0.8662602820211516), 4: np.float64(1.5785599571734474), 5: np.float64(1.329463480613165), 6: np.float64(0.6446764320069961), 7: np.float64(0.9017584097859327)}
# 30

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

y_probs = final_model.predict(X_test)
y_pred = np.argmax(y_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

print(classification_report(y_true, y_pred))
print(confusion_matrix(y_true, y_pred))
# Out:
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.45      0.62       244
#            1       0.99      0.97      0.98       624
#            2       0.92      0.83      0.87       311
#            3       0.58      0.84      0.69       579
#            4       0.95      0.60      0.74       243
#            5       0.72      0.71      0.71       284
#            6       0.95      0.95      0.95       666
#            7       0.99      1.00      0.99       470
#
#     accuracy                           0.85      3421
#    macro avg       0.88      0.79      0.82      3421
# weighted avg       0.88      0.85      0.85      3421
#
# [[111   1   0 118   3  11   0   0]
#  [  1 605   0  14   0   0   4   0]
#  [  0   1 257  36   3   1   7   6]
#  [  2   1   0 488   1  65  22   0]
#  [  0   0  23  73 147   0   0   0]
#  [  0   0   0  82   1 201   0   0]
#  [  0   1   0  31   0   1 633   0]
#  [  0   0   0   0   0   0   0 470]]

# %%
trainer_2 = SelfTrainingModel(model_NN=ResNet18, num_classes=8, initial_ratio=0.05, min_epochs=35, max_epochs=80)
final_model_2 = trainer_2.train(X_train, y_train, X_val, y_val)
# Out:
# X_labeled shape : (597, 28, 28, 3)
# X_unlabeled shape : (11362, 28, 28, 3)
#
# === Iteration 1: Training on 597 labeled samples ===
# 77
# Validation Accuracy after iteration 1: 0.2091
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [0.25       0.25       0.25       0.25       0.25       0.37315285
#  0.25       0.9       ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# Added 330 confident samples, 267 remain unlabeled.
#
# === Iteration 2: Training on 927 labeled samples ===
# 76
# Validation Accuracy after iteration 2: 0.6110
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [0.25       0.54976296 0.25       0.3048824  0.25       0.5240632
#  0.25       0.9       ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Added 461 confident samples, 136 remain unlabeled.
#
# === Iteration 3: Training on 1388 labeled samples ===
# 74
# Validation Accuracy after iteration 3: 0.6933
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [0.25       0.5796013  0.25       0.29110166 0.25       0.66231334
#  0.25       0.8687893 ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Added 522 confident samples, 75 remain unlabeled.
#
# === Iteration 4: Training on 1910 labeled samples ===
# 72
# Validation Accuracy after iteration 4: 0.7891
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [0.26558286 0.25       0.25       0.41221464 0.25       0.60534376
#  0.25       0.85512006]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Added 561 confident samples, 36 remain unlabeled.
#
# === Iteration 5: Training on 2471 labeled samples ===
# 70
# Validation Accuracy after iteration 5: 0.7967
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [0.25       0.3190128  0.25       0.25881213 0.25       0.47514504
#  0.2556984  0.8826128 ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Added 572 confident samples, 25 remain unlabeled.
#
# === Iteration 6: Training on 3043 labeled samples ===
# 68
# Validation Accuracy after iteration 6: 0.8002
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [0.25       0.31063572 0.25       0.49462846 0.25       0.4353995
#  0.25951052 0.8246063 ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Added 580 confident samples, 17 remain unlabeled.
#
# === Iteration 7: Training on 3623 labeled samples ===
# 66
# Validation Accuracy after iteration 7: 0.8201
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [0.25       0.50592494 0.25       0.65496796 0.25       0.43519777
#  0.42769325 0.7792496 ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Added 575 confident samples, 22 remain unlabeled.
#
# === Iteration 8: Training on 4198 labeled samples ===
# 64
# Validation Accuracy after iteration 8: 0.8306
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [0.25       0.63240725 0.25       0.34398395 0.25       0.4227493
#  0.34578472 0.73204607]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Added 592 confident samples, 5 remain unlabeled.
#
# === Iteration 9: Training on 4790 labeled samples ===
# 61
# Validation Accuracy after iteration 9: 0.8353
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [0.25       0.6920589  0.25       0.30318817 0.25       0.6598689
#  0.2720383  0.81979805]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Added 581 confident samples, 16 remain unlabeled.
#
# === Iteration 10: Training on 5371 labeled samples ===
# 59
# Validation Accuracy after iteration 10: 0.8370
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step
# Best thresholds  [0.25       0.7535966  0.26501274 0.42864728 0.25       0.25619924
#  0.30030075 0.7959211 ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Added 573 confident samples, 24 remain unlabeled.
#
# === Iteration 11: Training on 5944 labeled samples ===
# 57
# Validation Accuracy after iteration 11: 0.8388
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [0.25       0.5498095  0.25       0.5642848  0.25       0.25078785
#  0.3682732  0.858039  ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Added 586 confident samples, 11 remain unlabeled.
#
# === Iteration 12: Training on 6530 labeled samples ===
# 55
# Validation Accuracy after iteration 12: 0.8353
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [0.25       0.6728042  0.25       0.30501926 0.39022103 0.40237466
#  0.25       0.77191913]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Added 590 confident samples, 7 remain unlabeled.
#
# === Iteration 13: Training on 7120 labeled samples ===
# 53
# Validation Accuracy after iteration 13: 0.8440
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [0.25       0.5842489  0.25       0.34463677 0.33611634 0.8232287
#  0.34639424 0.82272744]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Added 577 confident samples, 20 remain unlabeled.
#
# === Iteration 14: Training on 7697 labeled samples ===
# 51
# Validation Accuracy after iteration 14: 0.8493
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [0.25       0.6266989  0.27745676 0.412444   0.25       0.28773788
#  0.4423088  0.8623645 ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Added 590 confident samples, 7 remain unlabeled.
#
# === Iteration 15: Training on 8287 labeled samples ===
# 48
# Validation Accuracy after iteration 15: 0.8388
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [0.25       0.51283836 0.25       0.35164884 0.25       0.65614104
#  0.5729551  0.6439975 ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Added 591 confident samples, 6 remain unlabeled.
#
# === Iteration 16: Training on 8878 labeled samples ===
# 46
# Validation Accuracy after iteration 16: 0.8405
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Best thresholds  [0.25       0.53262603 0.25       0.42666855 0.25       0.5604982
#  0.3892238  0.7746779 ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Added 588 confident samples, 9 remain unlabeled.
#
# === Iteration 17: Training on 9466 labeled samples ===
# 44
